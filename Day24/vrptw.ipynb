# %%
import os
from ortools.constraint_solver import pywrapcp, routing_enums_pb2
import numpy as np
import matplotlib.pyplot as plt

# %%
def parse_instance_file(file_name):
    coordinates = {}
    demands = {}
    time_windows = {}
    stand_times = {}
    dimension = None
    capacity = None
    capacity_vol = None

    with open(file_name, 'r') as file:
        lines = file.readlines()

    # Skip the initial comment section marked by ###
    lines = iter(lines)

    section = None
    for line in lines:
        line = line.strip()
        if line.startswith("DIMENSION"):
            dimension = int(line.split(':')[1].strip())
        elif line.startswith("CAPACITY "):
            capacity = int(line.split(':')[1].strip())
        elif line.startswith("CAPACITY_VOL"):
            capacity_vol = int(line.split(':')[1].strip())
        elif line == "NODE_COORD_SECTION":
            section = "coordinates"
            continue
        elif line == "PICKUP_SECTION":
            section = "pickups"
            continue            
        elif line == "DEMAND_SECTION":
            section = "demands"
            continue
        elif line == "TIME_WINDOW_SECTION":
            section = "time_windows"
            continue
        elif line == "STANDTIME_SECTION":
            section = "stand_times"
            continue
        elif line == "DEPOT_SECTION":
            section = "depot"
            continue
        elif line == "EOF":
            break

        if section == "coordinates" and line:
            parts = line.split()
            node_id, x, y = int(parts[0]) - 1, int(parts[1]), int(parts[2])
            coordinates[node_id] = (x, y)
        elif section == "demands" and line:
            parts = line.split()
            node_id, demand = int(parts[0]) - 1, int(parts[1])
            demands[node_id] = demand
        elif section == "time_windows" and line:
            parts = line.split()
            node_id = int(parts[0]) - 1
            begin_hh, begin_mm = map(int, parts[1].split(':'))
            end_hh, end_mm = map(int, parts[2].split(':'))
            time_windows[node_id] = (begin_hh * 60 + begin_mm, end_hh * 60 + end_mm)
        elif section == "stand_times" and line:
            parts = line.split()
            node_id, stand_time = int(parts[0]) - 1, int(parts[1])
            stand_times[node_id] = stand_time
        elif section == "depot" and line.isdigit():
            depot = int(line) - 1
    time_windows[0]=(0, 1440)
    return coordinates, demands, time_windows, stand_times, dimension, capacity, capacity_vol

def create_time_matrix(coordinates):
    locations = list(coordinates.values())
    time_matrix = {}
    speed = 1000  # Speed in km/h
    for from_index, from_node in enumerate(locations):
        time_matrix[from_index] = {}
        for to_index, to_node in enumerate(locations):
            if from_index == to_index:
                time_matrix[from_index][to_index] = 0
            else:
                distance = np.linalg.norm(np.array(from_node) - np.array(to_node))   # Distance in km
                time_matrix[from_index][to_index] = int(distance / speed * 60)  # Time in minutes
    return time_matrix

# %%
def print_solution(manager, routing, solution):
    time_dimension = routing.GetDimensionOrDie('Time')
    total_time = 0
    total_load = 0
    active_vehicles = 0
    for vehicle_id in range(routing.vehicles()):
        index = routing.Start(vehicle_id)
        plan_output = f'Route for vehicle {vehicle_id}:'
        route_time = 0
        route_load = 0
        route_nodes = []
        while not routing.IsEnd(index):
            node_index = manager.IndexToNode(index)
            route_nodes.append(node_index)  # Adjust node index to match original numbering
            route_load += data['demands'][node_index]
            previous_index = index
            index = solution.Value(routing.NextVar(index))
        route_time = solution.Value(time_dimension.CumulVar(index))
        if route_time > 0:
            active_vehicles += 1
            plan_output += ' -> '.join(map(str, route_nodes))
            plan_output += f'\nTime of the route: {route_time}m\n'
            plan_output += f'Load of the route: {route_load}\n'
            print(plan_output)
        total_time += route_time
        total_load += route_load
    print(f'Total time of all routes: {total_time}m')
    print(f'Total load of all routes: {total_load}')
    print(f'Total vehicles used: {active_vehicles}')

# %%
def plot_solution(coordinates, routes, times, time_windows):
    plt.figure(figsize=(30, 30))

    for vehicle_id, route in enumerate(routes):
        if len(route) <= 1:
            continue

        x_coords = [coordinates[node][0] for node in route]
        y_coords = [coordinates[node][1] for node in route]

        plt.plot(x_coords, y_coords, marker='o', label=f'Vehicle {vehicle_id}')

        for i, node in enumerate(route):
            x, y = coordinates[node]
            if i == 0:
                plt.text(x, y, f'{node}\nDepot', fontsize=8, ha='center')
            else:
                arrival_time = times[vehicle_id][i - 1]
                start, end = time_windows[node]
                plt.text(x, y, f'{node}\n{arrival_time // 60:02}:{arrival_time % 60}\n[{start // 60:02}:{start % 60}-{end // 60:02}:{end % 60}]',
                         fontsize=8, ha='center')

    plt.legend()
    plt.xlabel('X Coordinate')
    plt.ylabel('Y Coordinate')
    plt.title('Vehicle Routes')
    plt.grid()
    plt.savefig('routes.png')
    plt.show()

# %%
def extract_solution(manager, routing, solution, time_dimension):
    routes = []
    times = []
    for vehicle_id in range(routing.vehicles()):
        index = routing.Start(vehicle_id)
        route = []
        time = []
        while not routing.IsEnd(index):
            node_index = manager.IndexToNode(index)
            route.append(node_index)
            time.append(solution.Value(time_dimension.CumulVar(index)))
            index = solution.Value(routing.NextVar(index))
        routes.append(route)
        times.append(time)
    return routes, times

# %%
#os.chdir('Day24')  # Change to the appropriate folder
file_name = 'instance_clean.txt'

# Parse input data
coordinates, demands, time_windows, stand_times, dimension, capacity, capacity_vol = parse_instance_file(file_name)

# Define data model
data = {}
data['time_matrix'] = create_time_matrix(coordinates)
data['demands'] = list(demands.values())
data['time_windows'] = list(time_windows.values())
data['stand_times'] = list(stand_times.values())
# Example: 10 vehicles with given capacity
data['vehicle_capacities'] = [capacity] * 50
data['num_vehicles'] = len(data['vehicle_capacities'])
data['depot'] = 0

# %%
# Create the routing index manager
manager = pywrapcp.RoutingIndexManager(len(data['time_matrix']), data['num_vehicles'], data['depot'])

# Create Routing Model
#routing = pywrapcp.RoutingModel(manager)

routing_parameters = pywrapcp.DefaultRoutingModelParameters()
routing_parameters.solver_parameters.trace_propagation = True
routing_parameters.solver_parameters.trace_search = True
routing = pywrapcp.RoutingModel(manager)#, routing_parameters

# Create and register a transit callback
def time_callback(from_index, to_index):
    # Returns the travel time between the two nodes
    from_node = manager.IndexToNode(from_index)
    to_node = manager.IndexToNode(to_index)
    return data['time_matrix'][from_node][to_node] + data['stand_times'][from_node]

transit_callback_index = routing.RegisterTransitCallback(time_callback)

# Define cost of each arc
routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

# Add Capacity constraint
def demand_callback(from_index):
    # Returns the demand of the node
    from_node = manager.IndexToNode(from_index)
    return data['demands'][from_node]

demand_callback_index = routing.RegisterUnaryTransitCallback(demand_callback)
routing.AddDimensionWithVehicleCapacity(
    demand_callback_index,
    0,  # Null capacity slack
    data['vehicle_capacities'],  # Vehicle maximum capacities
    True,  # Start cumul to zero
    'Capacity')

# Add Time Window constraint
routing.AddDimension(
    transit_callback_index,
    1440,  # Allow waiting time
    1440,  # Maximum time per vehicle
    False,  # Don't force start cumul to zero
    'Time')


time_dimension = routing.GetDimensionOrDie('Time')
for location_idx, time_window in enumerate(data['time_windows']):
    if location_idx == data['depot']:
        continue
    index = manager.NodeToIndex(location_idx)
    time_dimension.CumulVar(index).SetRange(time_window[0], time_window[1])
# Add time window constraints for each vehicle start node.
depot_idx = data["depot"]
for vehicle_id in range(data["num_vehicles"]):
    index = routing.Start(vehicle_id)
    time_dimension.CumulVar(index).SetRange(
        data["time_windows"][depot_idx][0], data["time_windows"][depot_idx][1]
    )
for i in range(data["num_vehicles"]):
    routing.AddVariableMinimizedByFinalizer(
        time_dimension.CumulVar(routing.Start(i))
    )
    routing.AddVariableMinimizedByFinalizer(time_dimension.CumulVar(routing.End(i)))


# Setting search heuristic to Tabu Search
search_parameters = pywrapcp.DefaultRoutingSearchParameters()
#search_parameters.local_search_metaheuristic = (
#   routing_enums_pb2.LocalSearchMetaheuristic.TABU_SEARCH)
search_parameters.log_search = True


search_parameters.time_limit.seconds = 300


# Setting search heuristic to Greedy Algorithm
#search_parameters = pywrapcp.DefaultRoutingSearchParameters()
search_parameters.first_solution_strategy = (
    routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)
#search_parameters.time_limit.seconds = 30

# %%
def print_solution(manager, routing, solution, time_dimension, demands, time_windows):
    print("Solution Details:\n")
    active_vehicles = 0

    for vehicle_id in range(routing.vehicles()):
        index = routing.Start(vehicle_id)
        route = []
        times = []
        while not routing.IsEnd(index):
            node_index = manager.IndexToNode(index)
            arrival_time = solution.Value(time_dimension.CumulVar(index))
            route.append(
                (
                    node_index,
                    arrival_time,
                    time_windows[node_index],
                    demands[node_index],
                )
            )
            index = solution.Value(routing.NextVar(index))

        # Only print routes with non-zero length
        if len(route) > 1:
            active_vehicles += 1
            print(f"Vehicle {vehicle_id}:\n")
            for node, arrival, time_window, demand in route:
                #arrival_time_str = f"{arrival // 60:02}:{arrival % 60:02}"
                arrival_time_str = f"{arrival}"
                time_window_str = (
#                    f"[{time_window[0] // 60:02}:{time_window[0] % 60:02} - "
#                    f"{time_window[1] // 60:02}:{time_window[1] % 60:02}]"
                    f"[{time_window[0]} - "
                    f"{time_window[1]}]"
                    
                )
                print(
                    f"\tNode {node}, Arrival: {arrival_time_str}, "
                    f"Time Window: {time_window_str}, Demand: {demand}"
                )
            print("\n")

    print(f"Total active vehicles: {active_vehicles}\n")

# %%
# Solve the problem
print("Starting the solver...")
solution = routing.SolveWithParameters(search_parameters)

# Print solution and visualize
if solution:
    print("Solution found! Printing solution...")
    routes, times = extract_solution(manager, routing, solution, time_dimension)
    #plot_solution(coordinates, routes, times, data['time_windows'])
    print_solution(manager, routing, solution, time_dimension, demands, time_windows)
else:
    print("No solution found!")
# Out:
# Starting the solver...
# Solution found! Printing solution...
# Solution Details:
#
# Vehicle 42:
#
# 	Node 0, Arrival: 420, Time Window: [0 - 1440], Demand: 0
# 	Node 66, Arrival: 510, Time Window: [885 - 915], Demand: 3400
#
#
# Vehicle 43:
#
# 	Node 0, Arrival: 420, Time Window: [0 - 1440], Demand: 0
# 	Node 94, Arrival: 555, Time Window: [885 - 945], Demand: 2120
# 	Node 89, Arrival: 555, Time Window: [870 - 900], Demand: 1140
# 	Node 48, Arrival: 555, Time Window: [840 - 885], Demand: 1390
#
#
# Vehicle 44:
#
# 	Node 0, Arrival: 420, Time Window: [0 - 1440], Demand: 0
# 	Node 145, Arrival: 465, Time Window: [420 - 1080], Demand: 4910
# 	Node 98, Arrival: 615, Time Window: [810 - 870], Demand: 4250
# 	Node 54, Arrival: 615, Time Window: [420 - 1080], Demand: 4970
# 	Node 52, Arrival: 615, Time Window: [420 - 1080], Demand: 4750
# 	Node 41, Arrival: 615, Time Window: [750 - 780], Demand: 4510
# 	Node 37, Arrival: 615, Time Window: [420 - 1080], Demand: 3880
# 	Node 14, Arrival: 720, Time Window: [420 - 1080], Demand: 1420
# 	Node 2, Arrival: 720, Time Window: [420 - 1080], Demand: 1250
#
#
# Vehicle 45:
#
# 	Node 0, Arrival: 420, Time Window: [0 - 1440], Demand: 0
# 	Node 146, Arrival: 540, Time Window: [465 - 525], Demand: 2450
# 	Node 142, Arrival: 585, Time Window: [420 - 1080], Demand: 2210
# 	Node 118, Arrival: 615, Time Window: [750 - 780], Demand: 3070
# 	Node 115, Arrival: 615, Time Window: [420 - 1080], Demand: 1980
# 	Node 108, Arrival: 645, Time Window: [675 - 705], Demand: 4300
# 	Node 107, Arrival: 675, Time Window: [900 - 930], Demand: 1200
# 	Node 84, Arrival: 675, Time Window: [420 - 1080], Demand: 2040
# 	Node 82, Arrival: 675, Time Window: [420 - 1080], Demand: 3650
# 	Node 73, Arrival: 690, Time Window: [855 - 885], Demand: 3880
# 	Node 68, Arrival: 720, Time Window: [420 - 1080], Demand: 3760
# 	Node 49, Arrival: 735, Time Window: [510 - 570], Demand: 3220
# 	Node 40, Arrival: 750, Time Window: [420 - 1080], Demand: 2100
# 	Node 35, Arrival: 765, Time Window: [420 - 1080], Demand: 1850
# 	Node 33, Arrival: 765, Time Window: [870 - 915], Demand: 2720
# 	Node 31, Arrival: 765, Time Window: [420 - 1080], Demand: 3730
# 	Node 27, Arrival: 765, Time Window: [420 - 1080], Demand: 1640
# 	Node 25, Arrival: 810, Time Window: [420 - 1080], Demand: 4400
# 	Node 21, Arrival: 810, Time Window: [420 - 1080], Demand: 1310
# 	Node 19, Arrival: 810, Time Window: [420 - 1080], Demand: 1680
# 	Node 17, Arrival: 840, Time Window: [420 - 1080], Demand: 4300
# 	Node 15, Arrival: 840, Time Window: [720 - 780], Demand: 1920
# 	Node 9, Arrival: 840, Time Window: [420 - 1080], Demand: 2020
#
#
# Vehicle 46:
#
# 	Node 0, Arrival: 420, Time Window: [0 - 1440], Demand: 0
# 	Node 190, Arrival: 525, Time Window: [420 - 1080], Demand: 1950
# 	Node 180, Arrival: 540, Time Window: [900 - 945], Demand: 2390
# 	Node 178, Arrival: 555, Time Window: [945 - 975], Demand: 4890
# 	Node 154, Arrival: 615, Time Window: [780 - 825], Demand: 2760
# 	Node 147, Arrival: 675, Time Window: [540 - 585], Demand: 1060
# 	Node 134, Arrival: 750, Time Window: [930 - 960], Demand: 1840
# 	Node 117, Arrival: 750, Time Window: [825 - 870], Demand: 4070
# 	Node 100, Arrival: 750, Time Window: [420 - 1080], Demand: 1300
# 	Node 78, Arrival: 810, Time Window: [795 - 840], Demand: 4220
# 	Node 77, Arrival: 810, Time Window: [825 - 885], Demand: 2800
# 	Node 71, Arrival: 810, Time Window: [420 - 1080], Demand: 4070
# 	Node 63, Arrival: 810, Time Window: [420 - 1080], Demand: 2250
# 	Node 59, Arrival: 810, Time Window: [420 - 1080], Demand: 1810
# 	Node 46, Arrival: 810, Time Window: [840 - 885], Demand: 2100
# 	Node 44, Arrival: 810, Time Window: [420 - 1080], Demand: 1630
# 	Node 43, Arrival: 810, Time Window: [420 - 1080], Demand: 2480
# 	Node 42, Arrival: 810, Time Window: [585 - 630], Demand: 2580
# 	Node 39, Arrival: 810, Time Window: [900 - 930], Demand: 1290
# 	Node 38, Arrival: 900, Time Window: [570 - 630], Demand: 1390
# 	Node 36, Arrival: 900, Time Window: [765 - 810], Demand: 1930
# 	Node 34, Arrival: 900, Time Window: [765 - 795], Demand: 4390
# 	Node 32, Arrival: 900, Time Window: [765 - 825], Demand: 4490
# 	Node 30, Arrival: 900, Time Window: [420 - 1080], Demand: 3870
# 	Node 29, Arrival: 900, Time Window: [855 - 900], Demand: 2730
# 	Node 28, Arrival: 900, Time Window: [765 - 810], Demand: 3900
# 	Node 26, Arrival: 900, Time Window: [810 - 870], Demand: 1760
# 	Node 24, Arrival: 900, Time Window: [420 - 1080], Demand: 2450
# 	Node 23, Arrival: 900, Time Window: [420 - 1080], Demand: 3030
# 	Node 22, Arrival: 900, Time Window: [780 - 840], Demand: 4690
# 	Node 20, Arrival: 900, Time Window: [795 - 825], Demand: 2390
# 	Node 18, Arrival: 900, Time Window: [840 - 870], Demand: 4290
# 	Node 16, Arrival: 900, Time Window: [810 - 870], Demand: 2190
# 	Node 13, Arrival: 900, Time Window: [420 - 1080], Demand: 1710
# 	Node 12, Arrival: 900, Time Window: [420 - 1080], Demand: 3770
# 	Node 11, Arrival: 900, Time Window: [420 - 1080], Demand: 3740
# 	Node 10, Arrival: 900, Time Window: [825 - 870], Demand: 4960
# 	Node 8, Arrival: 900, Time Window: [420 - 1080], Demand: 2060
# 	Node 7, Arrival: 900, Time Window: [420 - 1080], Demand: 3440
# 	Node 6, Arrival: 900, Time Window: [420 - 1080], Demand: 2770
# 	Node 5, Arrival: 900, Time Window: [420 - 1080], Demand: 4990
# 	Node 4, Arrival: 900, Time Window: [420 - 1080], Demand: 1600
# 	Node 3, Arrival: 900, Time Window: [675 - 735], Demand: 2030
# 	Node 1, Arrival: 900, Time Window: [420 - 1080], Demand: 2290
#
#
# Vehicle 47:
#
# 	Node 0, Arrival: 420, Time Window: [0 - 1440], Demand: 0
# 	Node 195, Arrival: 630, Time Window: [930 - 990], Demand: 2230
# 	Node 193, Arrival: 705, Time Window: [420 - 1080], Demand: 4700
# 	Node 184, Arrival: 750, Time Window: [825 - 870], Demand: 4220
# 	Node 181, Arrival: 750, Time Window: [540 - 585], Demand: 3430
# 	Node 165, Arrival: 750, Time Window: [720 - 750], Demand: 2920
# 	Node 164, Arrival: 750, Time Window: [420 - 1080], Demand: 1770
# 	Node 153, Arrival: 780, Time Window: [420 - 1080], Demand: 4330
# 	Node 150, Arrival: 795, Time Window: [420 - 1080], Demand: 1430
# 	Node 116, Arrival: 825, Time Window: [615 - 675], Demand: 1280
# 	Node 97, Arrival: 825, Time Window: [840 - 900], Demand: 2090
# 	Node 91, Arrival: 825, Time Window: [420 - 1080], Demand: 2530
# 	Node 86, Arrival: 840, Time Window: [855 - 885], Demand: 4260
# 	Node 85, Arrival: 855, Time Window: [675 - 720], Demand: 1460
# 	Node 83, Arrival: 855, Time Window: [645 - 705], Demand: 4450
# 	Node 80, Arrival: 855, Time Window: [420 - 1080], Demand: 2190
# 	Node 79, Arrival: 855, Time Window: [810 - 840], Demand: 4880
# 	Node 76, Arrival: 855, Time Window: [855 - 900], Demand: 3790
# 	Node 75, Arrival: 855, Time Window: [420 - 1080], Demand: 2110
# 	Node 74, Arrival: 855, Time Window: [690 - 750], Demand: 4500
# 	Node 72, Arrival: 855, Time Window: [750 - 810], Demand: 2980
# 	Node 70, Arrival: 855, Time Window: [840 - 900], Demand: 1750
# 	Node 69, Arrival: 855, Time Window: [720 - 765], Demand: 4910
# 	Node 67, Arrival: 855, Time Window: [510 - 540], Demand: 3020
# 	Node 65, Arrival: 885, Time Window: [840 - 885], Demand: 4190
# 	Node 64, Arrival: 885, Time Window: [780 - 810], Demand: 3700
# 	Node 62, Arrival: 885, Time Window: [840 - 900], Demand: 3260
# 	Node 61, Arrival: 885, Time Window: [420 - 1080], Demand: 3830
# 	Node 60, Arrival: 885, Time Window: [780 - 810], Demand: 4570
# 	Node 58, Arrival: 885, Time Window: [420 - 1080], Demand: 2660
# 	Node 57, Arrival: 885, Time Window: [855 - 885], Demand: 4360
# 	Node 56, Arrival: 885, Time Window: [420 - 1080], Demand: 4740
# 	Node 55, Arrival: 885, Time Window: [615 - 660], Demand: 3240
# 	Node 53, Arrival: 885, Time Window: [600 - 645], Demand: 4460
# 	Node 51, Arrival: 885, Time Window: [870 - 915], Demand: 3740
# 	Node 50, Arrival: 885, Time Window: [735 - 765], Demand: 4430
# 	Node 47, Arrival: 885, Time Window: [780 - 825], Demand: 1770
# 	Node 45, Arrival: 885, Time Window: [420 - 1080], Demand: 4560
#
#
# Vehicle 48:
#
# 	Node 0, Arrival: 420, Time Window: [0 - 1440], Demand: 0
# 	Node 196, Arrival: 840, Time Window: [630 - 675], Demand: 1530
# 	Node 183, Arrival: 840, Time Window: [420 - 1080], Demand: 2560
# 	Node 170, Arrival: 885, Time Window: [420 - 1080], Demand: 1300
# 	Node 161, Arrival: 885, Time Window: [420 - 1080], Demand: 4280
# 	Node 155, Arrival: 885, Time Window: [615 - 675], Demand: 4380
# 	Node 151, Arrival: 885, Time Window: [795 - 855], Demand: 4760
# 	Node 143, Arrival: 885, Time Window: [585 - 645], Demand: 4400
# 	Node 132, Arrival: 885, Time Window: [870 - 900], Demand: 1950
# 	Node 131, Arrival: 885, Time Window: [420 - 1080], Demand: 3280
# 	Node 130, Arrival: 885, Time Window: [420 - 1080], Demand: 4510
# 	Node 129, Arrival: 885, Time Window: [420 - 1080], Demand: 4330
# 	Node 128, Arrival: 885, Time Window: [420 - 1080], Demand: 2680
# 	Node 127, Arrival: 885, Time Window: [855 - 900], Demand: 4570
# 	Node 126, Arrival: 885, Time Window: [870 - 915], Demand: 1420
# 	Node 125, Arrival: 885, Time Window: [420 - 1080], Demand: 3070
# 	Node 124, Arrival: 885, Time Window: [420 - 1080], Demand: 2910
# 	Node 123, Arrival: 885, Time Window: [420 - 1080], Demand: 2030
# 	Node 122, Arrival: 885, Time Window: [420 - 1080], Demand: 3890
# 	Node 121, Arrival: 885, Time Window: [420 - 1080], Demand: 4590
# 	Node 120, Arrival: 885, Time Window: [420 - 1080], Demand: 3420
# 	Node 119, Arrival: 885, Time Window: [615 - 675], Demand: 4340
# 	Node 114, Arrival: 885, Time Window: [420 - 1080], Demand: 1780
# 	Node 113, Arrival: 885, Time Window: [420 - 1080], Demand: 2970
# 	Node 112, Arrival: 885, Time Window: [420 - 1080], Demand: 2610
# 	Node 111, Arrival: 885, Time Window: [420 - 1080], Demand: 3800
# 	Node 110, Arrival: 885, Time Window: [900 - 930], Demand: 4230
# 	Node 109, Arrival: 900, Time Window: [645 - 690], Demand: 1420
# 	Node 106, Arrival: 900, Time Window: [420 - 1080], Demand: 3380
# 	Node 105, Arrival: 900, Time Window: [420 - 1080], Demand: 4730
# 	Node 103, Arrival: 900, Time Window: [420 - 1080], Demand: 4570
# 	Node 102, Arrival: 900, Time Window: [420 - 1080], Demand: 3650
# 	Node 101, Arrival: 900, Time Window: [690 - 750], Demand: 1620
# 	Node 99, Arrival: 900, Time Window: [615 - 645], Demand: 1840
# 	Node 96, Arrival: 900, Time Window: [885 - 915], Demand: 3340
# 	Node 95, Arrival: 900, Time Window: [555 - 585], Demand: 2030
# 	Node 93, Arrival: 900, Time Window: [420 - 1080], Demand: 4900
# 	Node 92, Arrival: 900, Time Window: [825 - 855], Demand: 2180
# 	Node 90, Arrival: 900, Time Window: [540 - 600], Demand: 2530
# 	Node 88, Arrival: 900, Time Window: [420 - 1080], Demand: 1000
# 	Node 87, Arrival: 900, Time Window: [840 - 900], Demand: 1180
# 	Node 81, Arrival: 900, Time Window: [420 - 1080], Demand: 1250
#
#
# Vehicle 49:
#
# 	Node 0, Arrival: 420, Time Window: [0 - 1440], Demand: 0
# 	Node 200, Arrival: 420, Time Window: [885 - 915], Demand: 3720
# 	Node 199, Arrival: 885, Time Window: [945 - 990], Demand: 2010
# 	Node 198, Arrival: 945, Time Window: [420 - 1080], Demand: 1220
# 	Node 197, Arrival: 945, Time Window: [840 - 870], Demand: 2830
# 	Node 194, Arrival: 945, Time Window: [705 - 750], Demand: 1080
# 	Node 192, Arrival: 945, Time Window: [420 - 1080], Demand: 3380
# 	Node 191, Arrival: 945, Time Window: [525 - 570], Demand: 1950
# 	Node 189, Arrival: 945, Time Window: [915 - 975], Demand: 3580
# 	Node 188, Arrival: 945, Time Window: [420 - 1080], Demand: 2950
# 	Node 187, Arrival: 945, Time Window: [420 - 1080], Demand: 3180
# 	Node 186, Arrival: 945, Time Window: [420 - 1080], Demand: 4050
# 	Node 185, Arrival: 945, Time Window: [750 - 810], Demand: 1980
# 	Node 182, Arrival: 945, Time Window: [735 - 795], Demand: 2600
# 	Node 179, Arrival: 945, Time Window: [555 - 615], Demand: 1440
# 	Node 177, Arrival: 945, Time Window: [945 - 975], Demand: 4020
# 	Node 176, Arrival: 945, Time Window: [420 - 1080], Demand: 3130
# 	Node 175, Arrival: 945, Time Window: [420 - 1080], Demand: 1630
# 	Node 174, Arrival: 945, Time Window: [420 - 1080], Demand: 4710
# 	Node 173, Arrival: 945, Time Window: [420 - 1080], Demand: 2390
# 	Node 172, Arrival: 945, Time Window: [420 - 1080], Demand: 3300
# 	Node 171, Arrival: 945, Time Window: [885 - 915], Demand: 4000
# 	Node 169, Arrival: 945, Time Window: [420 - 1080], Demand: 4000
# 	Node 168, Arrival: 945, Time Window: [915 - 960], Demand: 3220
# 	Node 167, Arrival: 945, Time Window: [420 - 1080], Demand: 1930
# 	Node 166, Arrival: 945, Time Window: [750 - 795], Demand: 4450
# 	Node 163, Arrival: 945, Time Window: [420 - 1080], Demand: 2990
# 	Node 162, Arrival: 945, Time Window: [870 - 930], Demand: 1840
# 	Node 160, Arrival: 945, Time Window: [420 - 1080], Demand: 1910
# 	Node 159, Arrival: 945, Time Window: [420 - 1080], Demand: 1970
# 	Node 158, Arrival: 945, Time Window: [420 - 1080], Demand: 2240
# 	Node 157, Arrival: 945, Time Window: [885 - 945], Demand: 3030
# 	Node 156, Arrival: 945, Time Window: [855 - 915], Demand: 4410
# 	Node 152, Arrival: 945, Time Window: [855 - 915], Demand: 2550
# 	Node 149, Arrival: 945, Time Window: [420 - 1080], Demand: 3250
# 	Node 148, Arrival: 945, Time Window: [675 - 735], Demand: 3040
# 	Node 144, Arrival: 945, Time Window: [855 - 885], Demand: 3990
# 	Node 141, Arrival: 945, Time Window: [420 - 1080], Demand: 1900
# 	Node 140, Arrival: 945, Time Window: [420 - 1080], Demand: 1840
# 	Node 139, Arrival: 945, Time Window: [885 - 945], Demand: 2230
# 	Node 138, Arrival: 945, Time Window: [915 - 945], Demand: 4890
# 	Node 137, Arrival: 945, Time Window: [420 - 1080], Demand: 1100
# 	Node 136, Arrival: 945, Time Window: [420 - 1080], Demand: 3670
# 	Node 135, Arrival: 945, Time Window: [750 - 780], Demand: 3020
# 	Node 133, Arrival: 945, Time Window: [420 - 1080], Demand: 1950
# 	Node 104, Arrival: 945, Time Window: [420 - 1080], Demand: 1030
#
#
# Total active vehicles: 8

# %%
time_matrix = create_time_matrix(coordinates)

# %%
time_matrix
# Out:
# {0: {0: 0,
#   1: 92,
#   2: 91,
#   3: 89,
#   4: 89,
#   5: 89,
#   6: 89,
#   7: 87,
#   8: 89,
#   9: 89,
#   10: 88,
#   11: 88,
#   12: 88,
#   13: 87,
#   14: 87,
#   15: 88,
#   16: 87,
#   17: 87,
#   18: 86,
#   19: 85,
#   20: 86,
#   21: 86,
#   22: 86,
#   23: 84,
#   24: 85,
#   25: 85,
#   26: 85,
#   27: 84,
#   28: 83,
#   29: 84,
#   30: 83,
#   31: 84,
#   32: 83,
#   33: 84,
#   34: 83,
#   35: 83,
#   36: 83,
#   37: 81,
#   38: 83,
#   39: 82,
#   40: 82,
#   41: 82,
#   42: 82,
#   43: 81,
#   44: 82,
#   45: 81,
#   46: 81,
#   47: 81,
#   48: 81,
#   49: 81,
#   50: 81,
#   51: 80,
#   52: 81,
#   53: 81,
#   54: 80,
#   55: 80,
#   56: 80,
#   57: 80,
#   58: 79,
#   59: 79,
#   60: 78,
#   61: 78,
#   62: 76,
#   63: 77,
#   64: 77,
#   65: 77,
#   66: 77,
#   67: 77,
#   68: 77,
#   69: 76,
#   70: 77,
#   71: 76,
#   72: 76,
#   73: 75,
#   74: 73,
#   75: 74,
#   76: 74,
#   77: 74,
#   78: 74,
#   79: 74,
#   80: 74,
#   81: 73,
#   82: 73,
#   83: 73,
#   84: 73,
#   85: 72,
#   86: 73,
#   87: 71,
#   88: 71,
#   89: 71,
#   90: 69,
#   91: 70,
#   92: 70,
#   93: 67,
#   94: 67,
#   95: 67,
#   96: 66,
#   97: 66,
#   98: 66,
#   99: 65,
#   100: 65,
#   101: 65,
#   102: 64,
#   103: 66,
#   104: 65,
#   105: 65,
#   106: 64,
#   107: 64,
#   108: 64,
#   109: 62,
#   110: 63,
#   111: 63,
#   112: 62,
#   113: 62,
#   114: 61,
#   115: 60,
#   116: 59,
#   117: 60,
#   118: 59,
#   119: 58,
#   120: 59,
#   121: 58,
#   122: 57,
#   123: 57,
#   124: 57,
#   125: 56,
#   126: 56,
#   127: 55,
#   128: 57,
#   129: 55,
#   130: 56,
#   131: 56,
#   132: 55,
#   133: 55,
#   134: 55,
#   135: 55,
#   136: 54,
#   137: 54,
#   138: 54,
#   139: 53,
#   140: 53,
#   141: 53,
#   142: 52,
#   143: 53,
#   144: 52,
#   145: 52,
#   146: 52,
#   147: 52,
#   148: 51,
#   149: 51,
#   150: 51,
#   151: 51,
#   152: 51,
#   153: 51,
#   154: 51,
#   155: 50,
#   156: 50,
#   157: 50,
#   158: 48,
#   159: 48,
#   160: 47,
#   161: 47,
#   162: 46,
#   163: 45,
#   164: 45,
#   165: 42,
#   166: 42,
#   167: 42,
#   168: 40,
#   169: 40,
#   170: 40,
#   171: 39,
#   172: 37,
#   173: 36,
#   174: 35,
#   175: 35,
#   176: 35,
#   177: 34,
#   178: 34,
#   179: 32,
#   180: 32,
#   181: 31,
#   182: 29,
#   183: 28,
#   184: 24,
#   185: 23,
#   186: 21,
#   187: 21,
#   188: 19,
#   189: 18,
#   190: 18,
#   191: 17,
#   192: 17,
#   193: 16,
#   194: 15,
#   195: 15,
#   196: 14,
#   197: 13,
#   198: 13,
#   199: 11,
#   200: 10},
#  1: {0: 92,
#   1: 0,
#   2: 77,
#   3: 52,
#   4: 43,
#   5: 3,
#   6: 59,
#   7: 72,
#   8: 4,
#   9: 181,
#   10: 76,
#   11: 6,
#   12: 20,
#   13: 134,
#   14: 28,
#   15: 41,
#   16: 179,
#   17: 40,
#   18: 11,
#   19: 176,
#   20: 128,
#   21: 45,
#   22: 53,
#   23: 11,
#   24: 75,
#   25: 26,
#   26: 46,
#   27: 167,
#   28: 12,
#   29: 176,
#   30: 168,
#   31: 111,
#   32: 12,
#   33: 111,
#   34: 17,
#   35: 58,
#   36: 52,
#   37: 71,
#   38: 52,
#   39: 14,
#   40: 71,
#   41: 77,
#   42: 10,
#   43: 28,
#   44: 41,
#   45: 50,
#   46: 72,
#   47: 72,
#   48: 53,
#   49: 14,
#   50: 152,
#   51: 46,
#   52: 27,
#   53: 38,
#   54: 73,
#   55: 17,
#   56: 17,
#   57: 52,
#   58: 33,
#   59: 16,
#   60: 166,
#   61: 45,
#   62: 69,
#   63: 34,
#   64: 112,
#   65: 34,
#   66: 75,
#   67: 15,
#   68: 121,
#   69: 74,
#   70: 53,
#   71: 94,
#   72: 168,
#   73: 23,
#   74: 63,
#   75: 21,
#   76: 18,
#   77: 17,
#   78: 20,
#   79: 47,
#   80: 92,
#   81: 166,
#   82: 37,
#   83: 165,
#   84: 165,
#   85: 28,
#   86: 42,
#   87: 162,
#   88: 85,
#   89: 71,
#   90: 29,
#   91: 40,
#   92: 24,
#   93: 31,
#   94: 41,
#   95: 46,
#   96: 28,
#   97: 84,
#   98: 80,
#   99: 36,
#   100: 28,
#   101: 63,
#   102: 88,
#   103: 55,
#   104: 27,
#   105: 71,
#   106: 33,
#   107: 74,
#   108: 55,
#   109: 67,
#   110: 117,
#   111: 77,
#   112: 43,
#   113: 72,
#   114: 39,
#   115: 72,
#   116: 88,
#   117: 76,
#   118: 86,
#   119: 145,
#   120: 131,
#   121: 44,
#   122: 43,
#   123: 104,
#   124: 102,
#   125: 69,
#   126: 44,
#   127: 88,
#   128: 148,
#   129: 88,
#   130: 76,
#   131: 81,
#   132: 144,
#   133: 79,
#   134: 79,
#   135: 87,
#   136: 80,
#   137: 124,
#   138: 84,
#   139: 74,
#   140: 79,
#   141: 43,
#   142: 66,
#   143: 43,
#   144: 143,
#   145: 41,
#   146: 63,
#   147: 57,
#   148: 78,
#   149: 44,
#   150: 41,
#   151: 79,
#   152: 138,
#   153: 77,
#   154: 41,
#   155: 42,
#   156: 76,
#   157: 76,
#   158: 70,
#   159: 82,
#   160: 105,
#   161: 81,
#   162: 128,
#   163: 52,
#   164: 136,
#   165: 49,
#   166: 117,
#   167: 91,
#   168: 125,
#   169: 121,
#   170: 64,
#   171: 120,
#   172: 68,
#   173: 78,
#   174: 127,
#   175: 119,
#   176: 56,
#   177: 118,
#   178: 109,
#   179: 63,
#   180: 121,
#   181: 107,
#   182: 85,
#   183: 117,
#   184: 113,
#   185: 82,
#   186: 112,
#   187: 72,
#   188: 110,
#   189: 108,
#   190: 108,
#   191: 99,
#   192: 105,
#   193: 92,
#   194: 77,
#   195: 96,
#   196: 104,
#   197: 102,
#   198: 91,
#   199: 98,
#   200: 93},
#  2: {0: 91,
#   1: 77,
#   2: 0,
#   3: 25,
#   4: 34,
#   5: 74,
#   6: 18,
#   7: 5,
#   8: 79,
#   9: 161,
#   10: 3,
#   11: 71,
#   12: 56,
#   13: 71,
#   14: 48,
#   15: 36,
#   16: 163,
#   17: 37,
#   18: 84,
#   19: 148,
#   20: 64,
#   21: 32,
#   22: 24,
#   23: 66,
#   24: 6,
#   25: 50,
#   26: 31,
#   27: 128,
#   28: 65,
#   29: 159,
#   30: 130,
#   31: 44,
#   32: 81,
#   33: 44,
#   34: 86,
#   35: 19,
#   36: 24,
#   37: 10,
#   38: 24,
#   39: 63,
#   40: 10,
#   41: 10,
#   42: 74,
#   43: 49,
#   44: 35,
#   45: 27,
#   46: 10,
#   47: 10,
#   48: 24,
#   49: 82,
#   50: 103,
#   51: 30,
#   52: 50,
#   53: 38,
#   54: 11,
#   55: 84,
#   56: 84,
#   57: 25,
#   58: 44,
#   59: 63,
#   60: 136,
#   61: 32,
#   62: 15,
#   63: 43,
#   64: 49,
#   65: 43,
#   66: 14,
#   67: 73,
#   68: 61,
#   69: 15,
#   70: 25,
#   71: 30,
#   72: 151,
#   73: 57,
#   74: 20,
#   75: 60,
#   76: 76,
#   77: 69,
#   78: 62,
#   79: 32,
#   80: 30,
#   81: 148,
#   82: 42,
#   83: 147,
#   84: 149,
#   85: 53,
#   86: 37,
#   87: 137,
#   88: 26,
#   89: 20,
#   90: 54,
#   91: 41,
#   92: 81,
#   93: 53,
#   94: 41,
#   95: 37,
#   96: 59,
#   97: 30,
#   98: 28,
#   99: 50,
#   100: 61,
#   101: 27,
#   102: 34,
#   103: 31,
#   104: 71,
#   105: 26,
#   106: 54,
#   107: 27,
#   108: 32,
#   109: 29,
#   110: 66,
#   111: 29,
#   112: 43,
#   113: 29,
#   114: 49,
#   115: 31,
#   116: 39,
#   117: 32,
#   118: 37,
#   119: 115,
#   120: 89,
#   121: 48,
#   122: 49,
#   123: 56,
#   124: 53,
#   125: 35,
#   126: 50,
#   127: 42,
#   128: 130,
#   129: 42,
#   130: 36,
#   131: 38,
#   132: 117,
#   133: 37,
#   134: 37,
#   135: 42,
#   136: 39,
#   137: 83,
#   138: 41,
#   139: 38,
#   140: 39,
#   141: 55,
#   142: 39,
#   143: 55,
#   144: 123,
#   145: 61,
#   146: 40,
#   147: 43,
#   148: 41,
#   149: 57,
#   150: 63,
#   151: 41,
#   152: 111,
#   153: 41,
#   154: 76,
#   155: 61,
#   156: 42,
#   157: 42,
#   158: 43,
#   159: 46,
#   160: 65,
#   161: 46,
#   162: 137,
#   163: 55,
#   164: 117,
#   165: 70,
#   166: 83,
#   167: 56,
#   168: 100,
#   169: 131,
#   170: 53,
#   171: 92,
#   172: 99,
#   173: 55,
#   174: 118,
#   175: 94,
#   176: 73,
#   177: 126,
#   178: 82,
#   179: 87,
#   180: 123,
#   181: 81,
#   182: 108,
#   183: 100,
#   184: 96,
#   185: 68,
#   186: 100,
#   187: 84,
#   188: 99,
#   189: 95,
#   190: 110,
#   191: 84,
#   192: 108,
#   193: 104,
#   194: 80,
#   195: 105,
#   196: 95,
#   197: 91,
#   198: 81,
#   199: 88,
#   200: 100},
#  3: {0: 89,
#   1: 52,
#   2: 25,
#   3: 0,
#   4: 9,
#   5: 49,
#   6: 6,
#   7: 21,
#   8: 54,
#   9: 169,
#   10: 24,
#   11: 47,
#   12: 31,
#   13: 92,
#   14: 23,
#   15: 11,
#   16: 170,
#   17: 12,
#   18: 61,
#   19: 158,
#   20: 86,
#   21: 7,
#   22: 3,
#   23: 42,
#   24: 25,
#   25: 25,
#   26: 6,
#   27: 142,
#   28: 41,
#   29: 166,
#   30: 143,
#   31: 66,
#   32: 58,
#   33: 66,
#   34: 63,
#   35: 9,
#   36: 6,
#   37: 23,
#   38: 6,
#   39: 40,
#   40: 22,
#   41: 28,
#   42: 51,
#   43: 25,
#   44: 12,
#   45: 7,
#   46: 24,
#   47: 24,
#   48: 8,
#   49: 59,
#   50: 119,
#   51: 9,
#   52: 26,
#   53: 15,
#   54: 25,
#   55: 61,
#   56: 61,
#   57: 8,
#   58: 21,
#   59: 40,
#   60: 146,
#   61: 12,
#   62: 23,
#   63: 21,
#   64: 70,
#   65: 21,
#   66: 29,
#   67: 51,
#   68: 80,
#   69: 28,
#   70: 12,
#   71: 49,
#   72: 157,
#   73: 34,
#   74: 20,
#   75: 38,
#   76: 54,
#   77: 47,
#   78: 40,
#   79: 15,
#   80: 49,
#   81: 154,
#   82: 21,
#   83: 154,
#   84: 155,
#   85: 32,
#   86: 18,
#   87: 146,
#   88: 42,
#   89: 29,
#   90: 33,
#   91: 23,
#   92: 60,
#   93: 34,
#   94: 25,
#   95: 23,
#   96: 40,
#   97: 43,
#   98: 40,
#   99: 32,
#   100: 41,
#   101: 27,
#   102: 49,
#   103: 23,
#   104: 51,
#   105: 32,
#   106: 36,
#   107: 35,
#   108: 25,
#   109: 31,
#   110: 82,
#   111: 39,
#   112: 29,
#   113: 35,
#   114: 33,
#   115: 36,
#   116: 52,
#   117: 40,
#   118: 49,
#   119: 125,
#   120: 103,
#   121: 34,
#   122: 35,
#   123: 70,
#   124: 67,
#   125: 38,
#   126: 36,
#   127: 54,
#   128: 136,
#   129: 54,
#   130: 43,
#   131: 47,
#   132: 126,
#   133: 45,
#   134: 45,
#   135: 53,
#   136: 47,
#   137: 96,
#   138: 51,
#   139: 43,
#   140: 47,
#   141: 41,
#   142: 39,
#   143: 41,
#   144: 129,
#   145: 46,
#   146: 38,
#   147: 37,
#   148: 47,
#   149: 43,
#   150: 48,
#   151: 48,
#   152: 120,
#   153: 47,
#   154: 60,
#   155: 47,
#   156: 47,
#   157: 47,
#   158: 44,
#   159: 52,
#   160: 76,
#   161: 52,
#   162: 135,
#   163: 45,
#   164: 123,
#   165: 57,
#   166: 93,
#   167: 64,
#   168: 108,
#   169: 128,
#   170: 49,
#   171: 100,
#   172: 87,
#   173: 57,
#   174: 121,
#   175: 101,
#   176: 62,
#   177: 123,
#   178: 89,
#   179: 76,
#   180: 122,
#   181: 88,
#   182: 99,
#   183: 104,
#   184: 100,
#   185: 69,
#   186: 102,
#   187: 77,
#   188: 101,
#   189: 97,
#   190: 108,
#   191: 87,
#   192: 106,
#   193: 99,
#   194: 75,
#   195: 100,
#   196: 96,
#   197: 93,
#   198: 81,
#   199: 89,
#   200: 96},
#  4: {0: 89,
#   1: 43,
#   2: 34,
#   3: 9,
#   4: 0,
#   5: 40,
#   6: 16,
#   7: 30,
#   8: 45,
#   9: 172,
#   10: 34,
#   11: 37,
#   12: 22,
#   13: 100,
#   14: 14,
#   15: 2,
#   16: 172,
#   17: 3,
#   18: 52,
#   19: 162,
#   20: 93,
#   21: 4,
#   22: 11,
#   23: 33,
#   24: 33,
#   25: 17,
#   26: 5,
#   27: 147,
#   28: 33,
#   29: 168,
#   30: 148,
#   31: 74,
#   32: 49,
#   33: 74,
#   34: 55,
#   35: 17,
#   36: 11,
#   37: 31,
#   38: 11,
#   39: 31,
#   40: 30,
#   41: 37,
#   42: 42,
#   43: 16,
#   44: 7,
#   45: 10,
#   46: 32,
#   47: 32,
#   48: 13,
#   49: 51,
#   50: 125,
#   51: 9,
#   52: 18,
#   53: 9,
#   54: 33,
#   55: 53,
#   56: 53,
#   57: 13,
#   58: 14,
#   59: 31,
#   60: 150,
#   61: 11,
#   62: 31,
#   63: 15,
#   64: 77,
#   65: 15,
#   66: 37,
#   67: 43,
#   68: 88,
#   69: 36,
#   70: 16,
#   71: 57,
#   72: 160,
#   73: 27,
#   74: 26,
#   75: 30,
#   76: 46,
#   77: 39,
#   78: 32,
#   79: 15,
#   80: 56,
#   81: 157,
#   82: 16,
#   83: 156,
#   84: 157,
#   85: 25,
#   86: 16,
#   87: 149,
#   88: 50,
#   89: 35,
#   90: 27,
#   91: 19,
#   92: 52,
#   93: 28,
#   94: 22,
#   95: 22,
#   96: 33,
#   97: 50,
#   98: 46,
#   99: 27,
#   100: 35,
#   101: 31,
#   102: 56,
#   103: 26,
#   104: 45,
#   105: 38,
#   106: 31,
#   107: 41,
#   108: 27,
#   109: 36,
#   110: 88,
#   111: 45,
#   112: 27,
#   113: 41,
#   114: 29,
#   115: 41,
#   116: 58,
#   117: 45,
#   118: 55,
#   119: 129,
#   120: 108,
#   121: 31,
#   122: 33,
#   123: 76,
#   124: 73,
#   125: 41,
#   126: 33,
#   127: 59,
#   128: 138,
#   129: 59,
#   130: 48,
#   131: 52,
#   132: 129,
#   133: 50,
#   134: 50,
#   135: 59,
#   136: 52,
#   137: 101,
#   138: 56,
#   139: 47,
#   140: 52,
#   141: 38,
#   142: 42,
#   143: 38,
#   144: 132,
#   145: 42,
#   146: 40,
#   147: 37,
#   148: 51,
#   149: 40,
#   150: 44,
#   151: 53,
#   152: 123,
#   153: 51,
#   154: 55,
#   155: 43,
#   156: 50,
#   157: 50,
#   158: 47,
#   159: 57,
#   160: 81,
#   161: 57,
#   162: 134,
#   163: 44,
#   164: 125,
#   165: 53,
#   166: 97,
#   167: 68,
#   168: 111,
#   169: 127,
#   170: 49,
#   171: 104,
#   172: 83,
#   173: 59,
#   174: 122,
#   175: 104,
#   176: 59,
#   177: 122,
#   178: 92,
#   179: 73,
#   180: 122,
#   181: 91,
#   182: 96,
#   183: 106,
#   184: 102,
#   185: 70,
#   186: 104,
#   187: 75,
#   188: 102,
#   189: 99,
#   190: 108,
#   191: 89,
#   192: 106,
#   193: 97,
#   194: 74,
#   195: 99,
#   196: 97,
#   197: 94,
#   198: 83,
#   199: 90,
#   200: 95},
#  5: {0: 89,
#   1: 3,
#   2: 74,
#   3: 49,
#   4: 40,
#   5: 0,
#   6: 56,
#   7: 68,
#   8: 5,
#   9: 178,
#   10: 72,
#   11: 2,
#   12: 18,
#   13: 130,
#   14: 25,
#   15: 38,
#   16: 176,
#   17: 37,
#   18: 12,
#   19: 172,
#   20: 124,
#   21: 42,
#   22: 50,
#   23: 7,
#   24: 71,
#   25: 23,
#   26: 43,
#   27: 164,
#   28: 8,
#   29: 173,
#   30: 164,
#   31: 107,
#   32: 11,
#   33: 107,
#   34: 17,
#   35: 54,
#   36: 49,
#   37: 68,
#   38: 49,
#   39: 10,
#   40: 67,
#   41: 73,
#   42: 7,
#   43: 25,
#   44: 38,
#   45: 46,
#   46: 69,
#   47: 69,
#   48: 49,
#   49: 14,
#   50: 148,
#   51: 43,
#   52: 24,
#   53: 35,
#   54: 69,
#   55: 16,
#   56: 16,
#   57: 49,
#   58: 30,
#   59: 12,
#   60: 163,
#   61: 41,
#   62: 66,
#   63: 30,
#   64: 109,
#   65: 30,
#   66: 72,
#   67: 12,
#   68: 117,
#   69: 70,
#   70: 50,
#   71: 90,
#   72: 165,
#   73: 19,
#   74: 59,
#   75: 17,
#   76: 15,
#   77: 14,
#   78: 16,
#   79: 43,
#   80: 89,
#   81: 162,
#   82: 34,
#   83: 162,
#   84: 162,
#   85: 24,
#   86: 38,
#   87: 159,
#   88: 82,
#   89: 67,
#   90: 25,
#   91: 36,
#   92: 22,
#   93: 27,
#   94: 37,
#   95: 42,
#   96: 24,
#   97: 80,
#   98: 76,
#   99: 32,
#   100: 24,
#   101: 59,
#   102: 85,
#   103: 51,
#   104: 24,
#   105: 67,
#   106: 29,
#   107: 70,
#   108: 52,
#   109: 63,
#   110: 113,
#   111: 73,
#   112: 40,
#   113: 68,
#   114: 36,
#   115: 68,
#   116: 84,
#   117: 72,
#   118: 82,
#   119: 141,
#   120: 127,
#   121: 40,
#   122: 39,
#   123: 101,
#   124: 98,
#   125: 65,
#   126: 40,
#   127: 84,
#   128: 145,
#   129: 84,
#   130: 73,
#   131: 77,
#   132: 140,
#   133: 75,
#   134: 75,
#   135: 83,
#   136: 76,
#   137: 120,
#   138: 80,
#   139: 70,
#   140: 75,
#   141: 39,
#   142: 63,
#   143: 39,
#   144: 140,
#   145: 38,
#   146: 59,
#   147: 53,
#   148: 74,
#   149: 41,
#   150: 38,
#   151: 75,
#   152: 134,
#   153: 73,
#   154: 39,
#   155: 39,
#   156: 72,
#   157: 72,
#   158: 66,
#   159: 78,
#   160: 101,
#   161: 77,
#   162: 126,
#   163: 48,
#   164: 132,
#   165: 46,
#   166: 113,
#   167: 87,
#   168: 122,
#   169: 119,
#   170: 60,
#   171: 117,
#   172: 66,
#   173: 74,
#   174: 124,
#   175: 115,
#   176: 53,
#   177: 115,
#   178: 106,
#   179: 61,
#   180: 118,
#   181: 104,
#   182: 82,
#   183: 113,
#   184: 109,
#   185: 78,
#   186: 109,
#   187: 69,
#   188: 107,
#   189: 104,
#   190: 105,
#   191: 96,
#   192: 102,
#   193: 90,
#   194: 74,
#   195: 93,
#   196: 101,
#   197: 98,
#   198: 88,
#   199: 94,
#   200: 90},
#  6: {0: 89,
#   1: 59,
#   2: 18,
#   3: 6,
#   4: 16,
#   5: 56,
#   6: 0,
#   7: 14,
#   8: 61,
#   9: 167,
#   10: 18,
#   11: 53,
#   12: 38,
#   13: 87,
#   14: 30,
#   15: 18,
#   16: 168,
#   17: 18,
#   18: 67,
#   19: 156,
#   20: 80,
#   21: 14,
#   22: 6,
#   23: 48,
#   24: 18,
#   25: 32,
#   26: 13,
#   27: 138,
#   28: 48,
#   29: 164,
#   30: 140,
#   31: 60,
#   32: 64,
#   33: 60,
#   34: 69,
#   35: 6,
#   36: 8,
#   37: 17,
#   38: 8,
#   39: 46,
#   40: 16,
#   41: 22,
#   42: 57,
#   43: 31,
#   44: 18,
#   45: 11,
#   46: 18,
#   47: 18,
#   48: 9,
#   49: 65,
#   50: 115,
#   51: 14,
#   52: 32,
#   53: 21,
#   54: 19,
#   55: 67,
#   56: 67,
#   57: 10,
#   58: 27,
#   59: 46,
#   60: 143,
#   61: 17,
#   62: 19,
#   63: 27,
#   64: 64,
#   65: 27,
#   66: 23,
#   67: 57,
#   68: 75,
#   69: 23,
#   70: 12,
#   71: 43,
#   72: 155,
#   73: 40,
#   74: 17,
#   75: 44,
#   76: 60,
#   77: 52,
#   78: 46,
#   79: 18,
#   80: 43,
#   81: 152,
#   82: 26,
#   83: 152,
#   84: 153,
#   85: 37,
#   86: 22,
#   87: 144,
#   88: 37,
#   89: 24,
#   90: 38,
#   91: 27,
#   92: 65,
#   93: 39,
#   94: 28,
#   95: 25,
#   96: 45,
#   97: 39,
#   98: 35,
#   99: 36,
#   100: 46,
#   101: 25,
#   102: 44,
#   103: 23,
#   104: 57,
#   105: 29,
#   106: 41,
#   107: 32,
#   108: 25,
#   109: 29,
#   110: 78,
#   111: 35,
#   112: 32,
#   113: 32,
#   114: 36,
#   115: 33,
#   116: 47,
#   117: 36,
#   118: 45,
#   119: 122,
#   120: 99,
#   121: 37,
#   122: 38,
#   123: 66,
#   124: 63,
#   125: 35,
#   126: 39,
#   127: 50,
#   128: 134,
#   129: 50,
#   130: 40,
#   131: 44,
#   132: 123,
#   133: 42,
#   134: 42,
#   135: 49,
#   136: 44,
#   137: 92,
#   138: 47,
#   139: 40,
#   140: 44,
#   141: 44,
#   142: 37,
#   143: 44,
#   144: 127,
#   145: 50,
#   146: 37,
#   147: 37,
#   148: 44,
#   149: 46,
#   150: 52,
#   151: 45,
#   152: 117,
#   153: 44,
#   154: 64,
#   155: 50,
#   156: 44,
#   157: 44,
#   158: 43,
#   159: 49,
#   160: 73,
#   161: 50,
#   162: 135,
#   163: 47,
#   164: 121,
#   165: 60,
#   166: 90,
#   167: 61,
#   168: 105,
#   169: 129,
#   170: 49,
#   171: 98,
#   172: 90,
#   173: 55,
#   174: 119,
#   175: 98,
#   176: 64,
#   177: 124,
#   178: 87,
#   179: 79,
#   180: 122,
#   181: 86,
#   182: 101,
#   183: 103,
#   184: 99,
#   185: 68,
#   186: 101,
#   187: 78,
#   188: 100,
#   189: 96,
#   190: 108,
#   191: 86,
#   192: 106,
#   193: 100,
#   194: 76,
#   195: 101,
#   196: 96,
#   197: 92,
#   198: 81,
#   199: 88,
#   200: 97},
#  7: {0: 87,
#   1: 72,
#   2: 5,
#   3: 21,
#   4: 30,
#   5: 68,
#   6: 14,
#   7: 0,
#   8: 73,
#   9: 159,
#   10: 3,
#   11: 66,
#   12: 51,
#   13: 73,
#   14: 43,
#   15: 31,
#   16: 161,
#   17: 32,
#   18: 79,
#   19: 147,
#   20: 66,
#   21: 27,
#   22: 19,
#   23: 61,
#   24: 4,
#   25: 45,
#   26: 26,
#   27: 128,
#   28: 60,
#   29: 157,
#   30: 130,
#   31: 46,
#   32: 76,
#   33: 46,
#   34: 81,
#   35: 14,
#   36: 19,
#   37: 6,
#   38: 19,
#   39: 58,
#   40: 5,
#   41: 9,
#   42: 69,
#   43: 43,
#   44: 30,
#   45: 22,
#   46: 6,
#   47: 6,
#   48: 19,
#   49: 76,
#   50: 103,
#   51: 25,
#   52: 44,
#   53: 33,
#   54: 7,
#   55: 78,
#   56: 78,
#   57: 19,
#   58: 38,
#   59: 57,
#   60: 134,
#   61: 27,
#   62: 11,
#   63: 38,
#   64: 51,
#   65: 38,
#   66: 12,
#   67: 68,
#   68: 62,
#   69: 12,
#   70: 19,
#   71: 30,
#   72: 149,
#   73: 51,
#   74: 15,
#   75: 55,
#   76: 70,
#   77: 63,
#   78: 56,
#   79: 26,
#   80: 31,
#   81: 146,
#   82: 36,
#   83: 145,
#   84: 147,
#   85: 48,
#   86: 31,
#   87: 136,
#   88: 25,
#   89: 17,
#   90: 48,
#   91: 35,
#   92: 75,
#   93: 48,
#   94: 36,
#   95: 32,
#   96: 54,
#   97: 28,
#   98: 26,
#   99: 44,
#   100: 55,
#   101: 23,
#   102: 34,
#   103: 26,
#   104: 66,
#   105: 23,
#   106: 49,
#   107: 24,
#   108: 27,
#   109: 25,
#   110: 66,
#   111: 27,
#   112: 38,
#   113: 26,
#   114: 43,
#   115: 27,
#   116: 38,
#   117: 29,
#   118: 36,
#   119: 114,
#   120: 89,
#   121: 42,
#   122: 44,
#   123: 55,
#   124: 52,
#   125: 31,
#   126: 44,
#   127: 41,
#   128: 127,
#   129: 41,
#   130: 33,
#   131: 36,
#   132: 116,
#   133: 35,
#   134: 35,
#   135: 41,
#   136: 36,
#   137: 82,
#   138: 39,
#   139: 35,
#   140: 37,
#   141: 50,
#   142: 35,
#   143: 50,
#   144: 121,
#   145: 56,
#   146: 36,
#   147: 38,
#   148: 38,
#   149: 51,
#   150: 58,
#   151: 39,
#   152: 109,
#   153: 38,
#   154: 70,
#   155: 56,
#   156: 39,
#   157: 39,
#   158: 39,
#   159: 43,
#   160: 64,
#   161: 43,
#   162: 134,
#   163: 50,
#   164: 115,
#   165: 64,
#   166: 82,
#   167: 54,
#   168: 98,
#   169: 128,
#   170: 49,
#   171: 90,
#   172: 94,
#   173: 51,
#   174: 115,
#   175: 92,
#   176: 68,
#   177: 122,
#   178: 80,
#   179: 82,
#   180: 119,
#   181: 79,
#   182: 103,
#   183: 97,
#   184: 93,
#   185: 65,
#   186: 97,
#   187: 80,
#   188: 96,
#   189: 92,
#   190: 106,
#   191: 81,
#   192: 105,
#   193: 100,
#   194: 75,
#   195: 101,
#   196: 92,
#   197: 88,
#   198: 77,
#   199: 85,
#   200: 96},
#  8: {0: 89,
#   1: 4,
#   2: 79,
#   3: 54,
#   4: 45,
#   5: 5,
#   6: 61,
#   7: 73,
#   8: 0,
#   9: 178,
#   10: 77,
#   11: 7,
#   12: 23,
#   13: 134,
#   14: 31,
#   15: 43,
#   16: 176,
#   17: 42,
#   18: 7,
#   19: 173,
#   20: 128,
#   21: 47,
#   22: 55,
#   23: 12,
#   24: 76,
#   25: 28,
#   26: 48,
#   27: 165,
#   28: 13,
#   29: 173,
#   30: 166,
#   31: 112,
#   32: 7,
#   33: 112,
#   34: 12,
#   35: 59,
#   36: 54,
#   37: 73,
#   38: 54,
#   39: 15,
#   40: 72,
#   41: 78,
#   42: 7,
#   43: 29,
#   44: 43,
#   45: 51,
#   46: 73,
#   47: 73,
#   48: 54,
#   49: 10,
#   50: 151,
#   51: 48,
#   52: 28,
#   53: 40,
#   54: 74,
#   55: 13,
#   56: 13,
#   57: 54,
#   58: 35,
#   59: 16,
#   60: 164,
#   61: 46,
#   62: 70,
#   63: 35,
#   64: 113,
#   65: 35,
#   66: 76,
#   67: 12,
#   68: 121,
#   69: 75,
#   70: 54,
#   71: 94,
#   72: 165,
#   73: 23,
#   74: 64,
#   75: 20,
#   76: 14,
#   77: 15,
#   78: 19,
#   79: 48,
#   80: 93,
#   81: 163,
#   82: 38,
#   83: 163,
#   84: 162,
#   85: 28,
#   86: 43,
#   87: 159,
#   88: 86,
#   89: 72,
#   90: 29,
#   91: 40,
#   92: 20,
#   93: 30,
#   94: 41,
#   95: 46,
#   96: 27,
#   97: 84,
#   98: 80,
#   99: 35,
#   100: 26,
#   101: 63,
#   102: 88,
#   103: 55,
#   104: 24,
#   105: 71,
#   106: 32,
#   107: 74,
#   108: 56,
#   109: 67,
#   110: 116,
#   111: 77,
#   112: 43,
#   113: 72,
#   114: 39,
#   115: 72,
#   116: 88,
#   117: 75,
#   118: 85,
#   119: 143,
#   120: 129,
#   121: 43,
#   122: 42,
#   123: 104,
#   124: 101,
#   125: 69,
#   126: 43,
#   127: 88,
#   128: 146,
#   129: 88,
#   130: 76,
#   131: 81,
#   132: 141,
#   133: 78,
#   134: 78,
#   135: 87,
#   136: 80,
#   137: 123,
#   138: 84,
#   139: 73,
#   140: 79,
#   141: 41,
#   142: 66,
#   143: 41,
#   144: 141,
#   145: 39,
#   146: 62,
#   147: 56,
#   148: 77,
#   149: 43,
#   150: 39,
#   151: 78,
#   152: 136,
#   153: 77,
#   154: 38,
#   155: 40,
#   156: 75,
#   157: 75,
#   158: 69,
#   159: 81,
#   160: 104,
#   161: 81,
#   162: 125,
#   163: 50,
#   164: 133,
#   165: 47,
#   166: 115,
#   167: 90,
#   168: 123,
#   169: 118,
#   170: 62,
#   171: 118,
#   172: 64,
#   173: 76,
#   174: 125,
#   175: 117,
#   176: 53,
#   177: 115,
#   178: 108,
#   179: 60,
#   180: 117,
#   181: 105,
#   182: 81,
#   183: 114,
#   184: 110,
#   185: 80,
#   186: 109,
#   187: 68,
#   188: 107,
#   189: 105,
#   190: 105,
#   191: 97,
#   192: 102,
#   193: 89,
#   194: 74,
#   195: 93,
#   196: 102,
#   197: 99,
#   198: 89,
#   199: 95,
#   200: 90},
#  9: {0: 89,
#   1: 181,
#   2: 161,
#   3: 169,
#   4: 172,
#   5: 178,
#   6: 167,
#   7: 159,
#   8: 178,
#   9: 0,
#   10: 158,
#   11: 177,
#   12: 175,
#   13: 112,
#   14: 173,
#   15: 171,
#   16: 7,
#   17: 170,
#   18: 176,
#   19: 19,
#   20: 117,
#   21: 168,
#   22: 165,
#   23: 173,
#   24: 156,
#   25: 171,
#   26: 167,
#   27: 48,
#   28: 172,
#   29: 7,
#   30: 45,
#   31: 131,
#   32: 173,
#   33: 131,
#   34: 172,
#   35: 161,
#   36: 163,
#   37: 153,
#   38: 163,
#   39: 171,
#   40: 154,
#   41: 151,
#   42: 171,
#   43: 168,
#   44: 165,
#   45: 162,
#   46: 152,
#   47: 152,
#   48: 161,
#   49: 170,
#   50: 77,
#   51: 162,
#   52: 167,
#   53: 165,
#   54: 152,
#   55: 169,
#   56: 169,
#   57: 160,
#   58: 164,
#   59: 167,
#   60: 31,
#   61: 160,
#   62: 149,
#   63: 163,
#   64: 122,
#   65: 163,
#   66: 147,
#   67: 166,
#   68: 112,
#   69: 146,
#   70: 157,
#   71: 134,
#   72: 12,
#   73: 163,
#   74: 149,
#   75: 163,
#   76: 164,
#   77: 163,
#   78: 163,
#   79: 156,
#   80: 133,
#   81: 15,
#   82: 158,
#   83: 15,
#   84: 16,
#   85: 159,
#   86: 156,
#   87: 24,
#   88: 135,
#   89: 143,
#   90: 157,
#   91: 154,
#   92: 159,
#   93: 155,
#   94: 152,
#   95: 150,
#   96: 154,
#   97: 131,
#   98: 133,
#   99: 151,
#   100: 154,
#   101: 142,
#   102: 127,
#   103: 146,
#   104: 154,
#   105: 138,
#   106: 151,
#   107: 135,
#   108: 144,
#   109: 138,
#   110: 99,
#   111: 132,
#   112: 147,
#   113: 134,
#   114: 147,
#   115: 133,
#   116: 122,
#   117: 130,
#   118: 124,
#   119: 46,
#   120: 75,
#   121: 144,
#   122: 143,
#   123: 106,
#   124: 109,
#   125: 131,
#   126: 142,
#   127: 118,
#   128: 33,
#   129: 118,
#   130: 127,
#   131: 123,
#   132: 44,
#   133: 125,
#   134: 125,
#   135: 118,
#   136: 123,
#   137: 80,
#   138: 120,
#   139: 126,
#   140: 123,
#   141: 140,
#   142: 130,
#   143: 140,
#   144: 39,
#   145: 140,
#   146: 131,
#   147: 134,
#   148: 122,
#   149: 138,
#   150: 140,
#   151: 121,
#   152: 50,
#   153: 122,
#   154: 140,
#   155: 139,
#   156: 122,
#   157: 122,
#   158: 124,
#   159: 117,
#   160: 96,
#   161: 117,
#   162: 68,
#   163: 132,
#   164: 46,
#   165: 131,
#   166: 77,
#   167: 105,
#   168: 61,
#   169: 73,
#   170: 123,
#   171: 69,
#   172: 121,
#   173: 112,
#   174: 53,
#   175: 68,
#   176: 125,
#   177: 72,
#   178: 80,
#   179: 120,
#   180: 65,
#   181: 81,
#   182: 105,
#   183: 65,
#   184: 69,
#   185: 102,
#   186: 69,
#   187: 110,
#   188: 71,
#   189: 74,
#   190: 75,
#   191: 83,
#   192: 78,
#   193: 92,
#   194: 103,
#   195: 88,
#   196: 76,
#   197: 79,
#   198: 90,
#   199: 83,
#   200: 89},
#  10: {0: 88,
#   1: 76,
#   2: 3,
#   3: 24,
#   4: 34,
#   5: 72,
#   6: 18,
#   7: 3,
#   8: 77,
#   9: 158,
#   10: 0,
#   11: 70,
#   12: 55,
#   13: 70,
#   14: 47,
#   15: 35,
#   16: 160,
#   17: 36,
#   18: 83,
#   19: 146,
#   20: 63,
#   21: 31,
#   22: 23,
#   23: 65,
#   24: 2,
#   25: 49,
#   26: 30,
#   27: 126,
#   28: 64,
#   29: 156,
#   30: 128,
#   31: 42,
#   32: 80,
#   33: 42,
#   34: 84,
#   35: 17,
#   36: 23,
#   37: 6,
#   38: 23,
#   39: 62,
#   40: 6,
#   41: 7,
#   42: 72,
#   43: 47,
#   44: 34,
#   45: 25,
#   46: 7,
#   47: 7,
#   48: 22,
#   49: 80,
#   50: 100,
#   51: 29,
#   52: 48,
#   53: 37,
#   54: 7,
#   55: 82,
#   56: 82,
#   57: 23,
#   58: 42,
#   59: 61,
#   60: 133,
#   61: 31,
#   62: 12,
#   63: 42,
#   64: 48,
#   65: 42,
#   66: 11,
#   67: 71,
#   68: 59,
#   69: 12,
#   70: 23,
#   71: 27,
#   72: 147,
#   73: 55,
#   74: 17,
#   75: 58,
#   76: 74,
#   77: 67,
#   78: 60,
#   79: 30,
#   80: 28,
#   81: 145,
#   82: 40,
#   83: 144,
#   84: 145,
#   85: 51,
#   86: 35,
#   87: 134,
#   88: 23,
#   89: 17,
#   90: 52,
#   91: 39,
#   92: 78,
#   93: 51,
#   94: 39,
#   95: 35,
#   96: 57,
#   97: 27,
#   98: 24,
#   99: 47,
#   100: 59,
#   101: 24,
#   102: 32,
#   103: 28,
#   104: 69,
#   105: 23,
#   106: 52,
#   107: 24,
#   108: 29,
#   109: 25,
#   110: 64,
#   111: 26,
#   112: 41,
#   113: 26,
#   114: 46,
#   115: 27,
#   116: 36,
#   117: 29,
#   118: 34,
#   119: 112,
#   120: 87,
#   121: 45,
#   122: 46,
#   123: 53,
#   124: 50,
#   125: 32,
#   126: 47,
#   127: 39,
#   128: 126,
#   129: 39,
#   130: 32,
#   131: 35,
#   132: 114,
#   133: 34,
#   134: 34,
#   135: 39,
#   136: 35,
#   137: 80,
#   138: 38,
#   139: 35,
#   140: 36,
#   141: 52,
#   142: 35,
#   143: 52,
#   144: 119,
#   145: 59,
#   146: 37,
#   147: 40,
#   148: 37,
#   149: 54,
#   150: 60,
#   151: 38,
#   152: 108,
#   153: 38,
#   154: 73,
#   155: 59,
#   156: 38,
#   157: 38,
#   158: 40,
#   159: 42,
#   160: 62,
#   161: 43,
#   162: 134,
#   163: 52,
#   164: 114,
#   165: 67,
#   166: 80,
#   167: 53,
#   168: 97,
#   169: 128,
#   170: 50,
#   171: 89,
#   172: 96,
#   173: 51,
#   174: 114,
#   175: 90,
#   176: 69,
#   177: 123,
#   178: 78,
#   179: 84,
#   180: 119,
#   181: 78,
#   182: 104,
#   183: 97,
#   184: 93,
#   185: 65,
#   186: 96,
#   187: 81,
#   188: 95,
#   189: 91,
#   190: 106,
#   191: 81,
#   192: 105,
#   193: 101,
#   194: 76,
#   195: 102,
#   196: 92,
#   197: 88,
#   198: 78,
#   199: 85,
#   200: 97},
#  11: {0: 88,
#   1: 6,
#   2: 71,
#   3: 47,
#   4: 37,
#   5: 2,
#   6: 53,
#   7: 66,
#   8: 7,
#   9: 177,
#   10: 70,
#   11: 0,
#   12: 15,
#   13: 128,
#   14: 23,
#   15: 35,
#   16: 175,
#   17: 34,
#   18: 14,
#   19: 171,
#   20: 122,
#   21: 39,
#   22: 47,
#   23: 5,
#   24: 69,
#   25: 21,
#   26: 40,
#   27: 162,
#   28: 6,
#   29: 171,
#   30: 162,
#   31: 105,
#   32: 13,
#   33: 105,
#   34: 19,
#   35: 52,
#   36: 46,
#   37: 65,
#   38: 46,
#   39: 8,
#   40: 65,
#   41: 71,
#   42: 8,
#   43: 22,
#   44: 35,
#   45: 44,
#   46: 66,
#   47: 66,
#   48: 47,
#   49: 15,
#   50: 146,
#   51: 40,
#   52: 21,
#   53: 32,
#   54: 67,
#   55: 18,
#   56: 18,
#   57: 46,
#   58: 27,
#   59: 10,
#   60: 161,
#   61: 39,
#   62: 63,
#   63: 28,
#   64: 106,
#   65: 28,
#   66: 69,
#   67: 12,
#   68: 115,
#   69: 67,
#   70: 47,
#   71: 87,
#   72: 164,
#   73: 17,
#   74: 56,
#   75: 15,
#   76: 16,
#   77: 13,
#   78: 14,
#   79: 41,
#   80: 86,
#   81: 161,
#   82: 31,
#   83: 161,
#   84: 161,
#   85: 21,
#   86: 36,
#   87: 157,
#   88: 79,
#   89: 65,
#   90: 23,
#   91: 33,
#   92: 23,
#   93: 25,
#   94: 35,
#   95: 39,
#   96: 23,
#   97: 77,
#   98: 73,
#   99: 29,
#   100: 23,
#   101: 56,
#   102: 82,
#   103: 49,
#   104: 23,
#   105: 64,
#   106: 27,
#   107: 68,
#   108: 49,
#   109: 60,
#   110: 111,
#   111: 71,
#   112: 37,
#   113: 66,
#   114: 33,
#   115: 65,
#   116: 82,
#   117: 69,
#   118: 79,
#   119: 140,
#   120: 125,
#   121: 38,
#   122: 37,
#   123: 98,
#   124: 95,
#   125: 63,
#   126: 38,
#   127: 82,
#   128: 144,
#   129: 82,
#   130: 70,
#   131: 75,
#   132: 139,
#   133: 72,
#   134: 72,
#   135: 81,
#   136: 74,
#   137: 118,
#   138: 78,
#   139: 68,
#   140: 73,
#   141: 37,
#   142: 60,
#   143: 37,
#   144: 138,
#   145: 36,
#   146: 57,
#   147: 51,
#   148: 72,
#   149: 39,
#   150: 36,
#   151: 73,
#   152: 133,
#   153: 71,
#   154: 38,
#   155: 37,
#   156: 70,
#   157: 70,
#   158: 64,
#   159: 76,
#   160: 99,
#   161: 75,
#   162: 125,
#   163: 46,
#   164: 131,
#   165: 45,
#   166: 111,
#   167: 85,
#   168: 120,
#   169: 118,
#   170: 58,
#   171: 115,
#   172: 66,
#   173: 72,
#   174: 123,
#   175: 114,
#   176: 52,
#   177: 115,
#   178: 104,
#   179: 60,
#   180: 117,
#   181: 102,
#   182: 82,
#   183: 112,
#   184: 108,
#   185: 77,
#   186: 107,
#   187: 68,
#   188: 105,
#   189: 103,
#   190: 104,
#   191: 94,
#   192: 101,
#   193: 89,
#   194: 73,
#   195: 93,
#   196: 100,
#   197: 97,
#   198: 87,
#   199: 93,
#   200: 90},
#  12: {0: 88,
#   1: 20,
#   2: 56,
#   3: 31,
#   4: 22,
#   5: 18,
#   6: 38,
#   7: 51,
#   8: 23,
#   9: 175,
#   10: 55,
#   11: 15,
#   12: 0,
#   13: 117,
#   14: 7,
#   15: 20,
#   16: 174,
#   17: 19,
#   18: 30,
#   19: 168,
#   20: 111,
#   21: 24,
#   22: 32,
#   23: 11,
#   24: 54,
#   25: 6,
#   26: 25,
#   27: 156,
#   28: 11,
#   29: 170,
#   30: 157,
#   31: 92,
#   32: 28,
#   33: 92,
#   34: 33,
#   35: 37,
#   36: 32,
#   37: 51,
#   38: 32,
#   39: 10,
#   40: 51,
#   41: 57,
#   42: 21,
#   43: 9,
#   44: 20,
#   45: 29,
#   46: 52,
#   47: 52,
#   48: 33,
#   49: 29,
#   50: 138,
#   51: 26,
#   52: 8,
#   53: 18,
#   54: 53,
#   55: 32,
#   56: 32,
#   57: 32,
#   58: 14,
#   59: 12,
#   60: 157,
#   61: 25,
#   62: 50,
#   63: 15,
#   64: 95,
#   65: 15,
#   66: 56,
#   67: 23,
#   68: 104,
#   69: 54,
#   70: 33,
#   71: 75,
#   72: 162,
#   73: 12,
#   74: 44,
#   75: 14,
#   76: 27,
#   77: 20,
#   78: 15,
#   79: 28,
#   80: 74,
#   81: 160,
#   82: 19,
#   83: 159,
#   84: 160,
#   85: 15,
#   86: 24,
#   87: 154,
#   88: 67,
#   89: 52,
#   90: 18,
#   91: 23,
#   92: 34,
#   93: 20,
#   94: 25,
#   95: 29,
#   96: 22,
#   97: 66,
#   98: 62,
#   99: 23,
#   100: 23,
#   101: 45,
#   102: 71,
#   103: 37,
#   104: 29,
#   105: 53,
#   106: 23,
#   107: 56,
#   108: 38,
#   109: 49,
#   110: 102,
#   111: 60,
#   112: 29,
#   113: 55,
#   114: 27,
#   115: 55,
#   116: 72,
#   117: 59,
#   118: 69,
#   119: 135,
#   120: 118,
#   121: 31,
#   122: 32,
#   123: 89,
#   124: 86,
#   125: 53,
#   126: 32,
#   127: 72,
#   128: 142,
#   129: 72,
#   130: 60,
#   131: 65,
#   132: 135,
#   133: 63,
#   134: 63,
#   135: 72,
#   136: 64,
#   137: 111,
#   138: 68,
#   139: 58,
#   140: 64,
#   141: 34,
#   142: 51,
#   143: 34,
#   144: 136,
#   145: 36,
#   146: 48,
#   147: 43,
#   148: 63,
#   149: 36,
#   150: 36,
#   151: 64,
#   152: 129,
#   153: 62,
#   154: 43,
#   155: 37,
#   156: 61,
#   157: 61,
#   158: 56,
#   159: 67,
#   160: 92,
#   161: 67,
#   162: 129,
#   163: 43,
#   164: 129,
#   165: 46,
#   166: 105,
#   167: 78,
#   168: 116,
#   169: 122,
#   170: 53,
#   171: 110,
#   172: 72,
#   173: 66,
#   174: 123,
#   175: 109,
#   176: 53,
#   177: 118,
#   178: 99,
#   179: 64,
#   180: 119,
#   181: 97,
#   182: 87,
#   183: 110,
#   184: 105,
#   185: 73,
#   186: 106,
#   187: 70,
#   188: 104,
#   189: 101,
#   190: 105,
#   191: 92,
#   192: 103,
#   193: 92,
#   194: 72,
#   195: 95,
#   196: 99,
#   197: 95,
#   198: 84,
#   199: 91,
#   200: 91},
#  13: {0: 87,
#   1: 134,
#   2: 71,
#   3: 92,
#   4: 100,
#   5: 130,
#   6: 87,
#   7: 73,
#   8: 134,
#   9: 112,
#   10: 70,
#   11: 128,
#   12: 117,
#   13: 0,
#   14: 110,
#   15: 101,
#   16: 117,
#   17: 101,
#   18: 137,
#   19: 95,
#   20: 7,
#   21: 96,
#   22: 89,
#   23: 123,
#   24: 69,
#   25: 111,
#   26: 95,
#   27: 68,
#   28: 122,
#   29: 113,
#   30: 71,
#   31: 27,
#   32: 133,
#   33: 27,
#   34: 136,
#   35: 83,
#   36: 88,
#   37: 69,
#   38: 88,
#   39: 120,
#   40: 70,
#   41: 64,
#   42: 127,
#   43: 108,
#   44: 97,
#   45: 90,
#   46: 68,
#   47: 68,
#   48: 87,
#   49: 132,
#   50: 37,
#   51: 92,
#   52: 108,
#   53: 99,
#   54: 67,
#   55: 133,
#   56: 133,
#   57: 87,
#   58: 102,
#   59: 117,
#   60: 81,
#   61: 92,
#   62: 69,
#   63: 101,
#   64: 22,
#   65: 101,
#   66: 63,
#   67: 124,
#   68: 13,
#   69: 64,
#   70: 84,
#   71: 43,
#   72: 106,
#   73: 111,
#   74: 74,
#   75: 113,
#   76: 125,
#   77: 119,
#   78: 114,
#   79: 89,
#   80: 43,
#   81: 103,
#   82: 97,
#   83: 102,
#   84: 105,
#   85: 106,
#   86: 93,
#   87: 89,
#   88: 50,
#   89: 65,
#   90: 105,
#   91: 94,
#   92: 126,
#   93: 103,
#   94: 92,
#   95: 88,
#   96: 107,
#   97: 50,
#   98: 54,
#   99: 98,
#   100: 108,
#   101: 71,
#   102: 45,
#   103: 79,
#   104: 116,
#   105: 63,
#   106: 102,
#   107: 60,
#   108: 78,
#   109: 67,
#   110: 24,
#   111: 57,
#   112: 90,
#   113: 62,
#   114: 95,
#   115: 62,
#   116: 45,
#   117: 58,
#   118: 48,
#   119: 68,
#   120: 39,
#   121: 91,
#   122: 92,
#   123: 33,
#   124: 34,
#   125: 65,
#   126: 92,
#   127: 46,
#   128: 89,
#   129: 46,
#   130: 57,
#   131: 53,
#   132: 72,
#   133: 55,
#   134: 55,
#   135: 47,
#   136: 54,
#   137: 38,
#   138: 50,
#   139: 60,
#   140: 55,
#   141: 95,
#   142: 68,
#   143: 95,
#   144: 82,
#   145: 99,
#   146: 72,
#   147: 78,
#   148: 57,
#   149: 94,
#   150: 100,
#   151: 56,
#   152: 68,
#   153: 57,
#   154: 111,
#   155: 98,
#   156: 59,
#   157: 59,
#   158: 65,
#   159: 54,
#   160: 40,
#   161: 55,
#   162: 121,
#   163: 88,
#   164: 81,
#   165: 100,
#   166: 49,
#   167: 50,
#   168: 64,
#   169: 118,
#   170: 76,
#   171: 57,
#   172: 117,
#   173: 64,
#   174: 90,
#   175: 62,
#   176: 97,
#   177: 113,
#   178: 55,
#   179: 107,
#   180: 105,
#   181: 57,
#   182: 116,
#   183: 73,
#   184: 72,
#   185: 70,
#   186: 78,
#   187: 97,
#   188: 79,
#   189: 76,
#   190: 97,
#   191: 70,
#   192: 98,
#   193: 104,
#   194: 87,
#   195: 102,
#   196: 79,
#   197: 77,
#   198: 74,
#   199: 77,
#   200: 97},
#  14: {0: 87,
#   1: 28,
#   2: 48,
#   3: 23,
#   4: 14,
#   5: 25,
#   6: 30,
#   7: 43,
#   8: 31,
#   9: 173,
#   10: 47,
#   11: 23,
#   12: 7,
#   13: 110,
#   14: 0,
#   15: 12,
#   16: 172,
#   17: 11,
#   18: 37,
#   19: 165,
#   20: 104,
#   21: 16,
#   22: 24,
#   23: 18,
#   24: 47,
#   25: 2,
#   26: 17,
#   27: 152,
#   28: 18,
#   29: 169,
#   30: 153,
#   31: 86,
#   32: 35,
#   33: 86,
#   34: 40,
#   35: 30,
#   36: 24,
#   37: 44,
#   38: 24,
#   39: 16,
#   40: 43,
#   41: 49,
#   42: 28,
#   43: 5,
#   44: 13,
#   45: 22,
#   46: 45,
#   47: 45,
#   48: 25,
#   49: 36,
#   50: 133,
#   51: 19,
#   52: 6,
#   53: 11,
#   54: 45,
#   55: 39,
#   56: 39,
#   57: 24,
#   58: 8,
#   59: 17,
#   60: 154,
#   61: 18,
#   62: 42,
#   63: 10,
#   64: 88,
#   65: 10,
#   66: 49,
#   67: 29,
#   68: 97,
#   69: 47,
#   70: 26,
#   71: 68,
#   72: 161,
#   73: 15,
#   74: 37,
#   75: 18,
#   76: 33,
#   77: 25,
#   78: 20,
#   79: 21,
#   80: 67,
#   81: 158,
#   82: 15,
#   83: 157,
#   84: 158,
#   85: 15,
#   86: 18,
#   87: 152,
#   88: 60,
#   89: 45,
#   90: 18,
#   91: 18,
#   92: 39,
#   93: 20,
#   94: 21,
#   95: 24,
#   96: 24,
#   97: 60,
#   98: 55,
#   99: 22,
#   100: 25,
#   101: 39,
#   102: 65,
#   103: 32,
#   104: 33,
#   105: 47,
#   106: 23,
#   107: 50,
#   108: 33,
#   109: 43,
#   110: 96,
#   111: 54,
#   112: 26,
#   113: 49,
#   114: 25,
#   115: 49,
#   116: 66,
#   117: 53,
#   118: 63,
#   119: 132,
#   120: 114,
#   121: 29,
#   122: 30,
#   123: 84,
#   124: 81,
#   125: 48,
#   126: 30,
#   127: 67,
#   128: 140,
#   129: 67,
#   130: 55,
#   131: 60,
#   132: 132,
#   133: 57,
#   134: 57,
#   135: 66,
#   136: 59,
#   137: 106,
#   138: 63,
#   139: 53,
#   140: 58,
#   141: 33,
#   142: 47,
#   143: 33,
#   144: 134,
#   145: 36,
#   146: 44,
#   147: 39,
#   148: 57,
#   149: 36,
#   150: 37,
#   151: 59,
#   152: 126,
#   153: 57,
#   154: 46,
#   155: 37,
#   156: 56,
#   157: 56,
#   158: 52,
#   159: 62,
#   160: 87,
#   161: 62,
#   162: 130,
#   163: 41,
#   164: 127,
#   165: 47,
#   166: 101,
#   167: 73,
#   168: 113,
#   169: 123,
#   170: 50,
#   171: 107,
#   172: 74,
#   173: 62,
#   174: 121,
#   175: 106,
#   176: 53,
#   177: 118,
#   178: 96,
#   179: 66,
#   180: 119,
#   181: 94,
#   182: 89,
#   183: 107,
#   184: 103,
#   185: 70,
#   186: 104,
#   187: 70,
#   188: 102,
#   189: 99,
#   190: 105,
#   191: 89,
#   192: 103,
#   193: 93,
#   194: 72,
#   195: 95,
#   196: 97,
#   197: 94,
#   198: 82,
#   199: 90,
#   200: 91},
#  15: {0: 88,
#   1: 41,
#   2: 36,
#   3: 11,
#   4: 2,
#   5: 38,
#   6: 18,
#   7: 31,
#   8: 43,
#   9: 171,
#   10: 35,
#   11: 35,
#   12: 20,
#   13: 101,
#   14: 12,
#   15: 0,
#   16: 171,
#   17: 0,
#   18: 49,
#   19: 162,
#   20: 94,
#   21: 4,
#   22: 12,
#   23: 31,
#   24: 35,
#   25: 14,
#   26: 6,
#   27: 147,
#   28: 30,
#   29: 167,
#   30: 148,
#   31: 75,
#   32: 47,
#   33: 75,
#   34: 52,
#   35: 18,
#   36: 13,
#   37: 33,
#   38: 13,
#   39: 28,
#   40: 32,
#   41: 38,
#   42: 40,
#   43: 14,
#   44: 5,
#   45: 11,
#   46: 34,
#   47: 34,
#   48: 14,
#   49: 48,
#   50: 126,
#   51: 9,
#   52: 15,
#   53: 7,
#   54: 34,
#   55: 50,
#   56: 50,
#   57: 14,
#   58: 11,
#   59: 29,
#   60: 150,
#   61: 10,
#   62: 32,
#   63: 12,
#   64: 78,
#   65: 12,
#   66: 38,
#   67: 40,
#   68: 88,
#   69: 37,
#   70: 17,
#   71: 58,
#   72: 159,
#   73: 24,
#   74: 27,
#   75: 28,
#   76: 44,
#   77: 36,
#   78: 30,
#   79: 14,
#   80: 57,
#   81: 156,
#   82: 15,
#   83: 156,
#   84: 156,
#   85: 23,
#   86: 14,
#   87: 149,
#   88: 51,
#   89: 36,
#   90: 25,
#   91: 18,
#   92: 50,
#   93: 26,
#   94: 20,
#   95: 21,
#   96: 31,
#   97: 51,
#   98: 47,
#   99: 25,
#   100: 33,
#   101: 31,
#   102: 56,
#   103: 25,
#   104: 42,
#   105: 38,
#   106: 29,
#   107: 42,
#   108: 27,
#   109: 36,
#   110: 89,
#   111: 45,
#   112: 25,
#   113: 41,
#   114: 27,
#   115: 42,
#   116: 58,
#   117: 45,
#   118: 55,
#   119: 128,
#   120: 108,
#   121: 30,
#   122: 31,
#   123: 76,
#   124: 73,
#   125: 41,
#   126: 32,
#   127: 59,
#   128: 138,
#   129: 59,
#   130: 48,
#   131: 53,
#   132: 129,
#   133: 50,
#   134: 50,
#   135: 59,
#   136: 52,
#   137: 101,
#   138: 56,
#   139: 47,
#   140: 52,
#   141: 36,
#   142: 42,
#   143: 36,
#   144: 131,
#   145: 40,
#   146: 40,
#   147: 37,
#   148: 51,
#   149: 38,
#   150: 42,
#   151: 53,
#   152: 123,
#   153: 51,
#   154: 53,
#   155: 41,
#   156: 50,
#   157: 50,
#   158: 47,
#   159: 56,
#   160: 81,
#   161: 56,
#   162: 132,
#   163: 42,
#   164: 125,
#   165: 52,
#   166: 97,
#   167: 68,
#   168: 110,
#   169: 125,
#   170: 48,
#   171: 103,
#   172: 81,
#   173: 59,
#   174: 121,
#   175: 103,
#   176: 57,
#   177: 121,
#   178: 92,
#   179: 71,
#   180: 120,
#   181: 91,
#   182: 94,
#   183: 106,
#   184: 101,
#   185: 69,
#   186: 103,
#   187: 73,
#   188: 102,
#   189: 98,
#   190: 106,
#   191: 88,
#   192: 104,
#   193: 95,
#   194: 73,
#   195: 98,
#   196: 96,
#   197: 93,
#   198: 82,
#   199: 89,
#   200: 93},
#  16: {0: 87,
#   1: 179,
#   2: 163,
#   3: 170,
#   4: 172,
#   5: 176,
#   6: 168,
#   7: 161,
#   8: 176,
#   9: 7,
#   10: 160,
#   11: 175,
#   12: 174,
#   13: 117,
#   14: 172,
#   15: 171,
#   16: 0,
#   17: 170,
#   18: 174,
#   19: 25,
#   20: 121,
#   21: 168,
#   22: 166,
#   23: 172,
#   24: 157,
#   25: 171,
#   26: 167,
#   27: 54,
#   28: 171,
#   29: 3,
#   30: 51,
#   31: 134,
#   32: 171,
#   33: 134,
#   34: 170,
#   35: 162,
#   36: 163,
#   37: 155,
#   38: 163,
#   39: 170,
#   40: 155,
#   41: 152,
#   42: 169,
#   43: 167,
#   44: 165,
#   45: 163,
#   46: 154,
#   47: 154,
#   48: 161,
#   49: 168,
#   50: 82,
#   51: 162,
#   52: 167,
#   53: 165,
#   54: 153,
#   55: 167,
#   56: 167,
#   57: 161,
#   58: 164,
#   59: 166,
#   60: 37,
#   61: 160,
#   62: 150,
#   63: 162,
#   64: 125,
#   65: 162,
#   66: 148,
#   67: 164,
#   68: 116,
#   69: 148,
#   70: 157,
#   71: 137,
#   72: 12,
#   73: 162,
#   74: 150,
#   75: 162,
#   76: 162,
#   77: 162,
#   78: 161,
#   79: 156,
#   80: 135,
#   81: 15,
#   82: 158,
#   83: 16,
#   84: 14,
#   85: 159,
#   86: 156,
#   87: 28,
#   88: 137,
#   89: 144,
#   90: 156,
#   91: 154,
#   92: 157,
#   93: 154,
#   94: 152,
#   95: 150,
#   96: 153,
#   97: 133,
#   98: 135,
#   99: 151,
#   100: 153,
#   101: 142,
#   102: 128,
#   103: 146,
#   104: 152,
#   105: 139,
#   106: 151,
#   107: 136,
#   108: 145,
#   109: 138,
#   110: 102,
#   111: 134,
#   112: 147,
#   113: 136,
#   114: 147,
#   115: 134,
#   116: 123,
#   117: 132,
#   118: 125,
#   119: 49,
#   120: 79,
#   121: 143,
#   122: 142,
#   123: 109,
#   124: 111,
#   125: 132,
#   126: 142,
#   127: 120,
#   128: 33,
#   129: 120,
#   130: 128,
#   131: 125,
#   132: 46,
#   133: 126,
#   134: 126,
#   135: 120,
#   136: 124,
#   137: 84,
#   138: 121,
#   139: 127,
#   140: 124,
#   141: 140,
#   142: 130,
#   143: 140,
#   144: 40,
#   145: 139,
#   146: 131,
#   147: 134,
#   148: 123,
#   149: 138,
#   150: 138,
#   151: 122,
#   152: 52,
#   153: 123,
#   154: 138,
#   155: 138,
#   156: 123,
#   157: 123,
#   158: 125,
#   159: 118,
#   160: 98,
#   161: 118,
#   162: 63,
#   163: 131,
#   164: 46,
#   165: 130,
#   166: 80,
#   167: 107,
#   168: 63,
#   169: 68,
#   170: 122,
#   171: 71,
#   172: 118,
#   173: 112,
#   174: 51,
#   175: 69,
#   176: 123,
#   177: 68,
#   178: 81,
#   179: 118,
#   180: 61,
#   181: 82,
#   182: 102,
#   183: 65,
#   184: 69,
#   185: 102,
#   186: 68,
#   187: 108,
#   188: 70,
#   189: 73,
#   190: 72,
#   191: 83,
#   192: 75,
#   193: 89,
#   194: 102,
#   195: 85,
#   196: 75,
#   197: 78,
#   198: 90,
#   199: 82,
#   200: 87},
#  17: {0: 87,
#   1: 40,
#   2: 37,
#   3: 12,
#   4: 3,
#   5: 37,
#   6: 18,
#   7: 32,
#   8: 42,
#   9: 170,
#   10: 36,
#   11: 34,
#   12: 19,
#   13: 101,
#   14: 11,
#   15: 0,
#   16: 170,
#   17: 0,
#   18: 49,
#   19: 161,
#   20: 95,
#   21: 5,
#   22: 13,
#   23: 30,
#   24: 36,
#   25: 13,
#   26: 6,
#   27: 147,
#   28: 29,
#   29: 167,
#   30: 148,
#   31: 75,
#   32: 46,
#   33: 75,
#   34: 51,
#   35: 18,
#   36: 13,
#   37: 33,
#   38: 13,
#   39: 28,
#   40: 32,
#   41: 39,
#   42: 39,
#   43: 13,
#   44: 5,
#   45: 11,
#   46: 34,
#   47: 34,
#   48: 14,
#   49: 47,
#   50: 126,
#   51: 9,
#   52: 14,
#   53: 6,
#   54: 35,
#   55: 50,
#   56: 50,
#   57: 14,
#   58: 10,
#   59: 28,
#   60: 150,
#   61: 10,
#   62: 32,
#   63: 11,
#   64: 79,
#   65: 11,
#   66: 38,
#   67: 39,
#   68: 89,
#   69: 37,
#   70: 17,
#   71: 58,
#   72: 158,
#   73: 23,
#   74: 27,
#   75: 27,
#   76: 43,
#   77: 35,
#   78: 29,
#   79: 14,
#   80: 58,
#   81: 156,
#   82: 14,
#   83: 155,
#   84: 156,
#   85: 22,
#   86: 14,
#   87: 148,
#   88: 51,
#   89: 36,
#   90: 24,
#   91: 17,
#   92: 49,
#   93: 25,
#   94: 19,
#   95: 20,
#   96: 30,
#   97: 51,
#   98: 47,
#   99: 24,
#   100: 32,
#   101: 31,
#   102: 56,
#   103: 25,
#   104: 41,
#   105: 38,
#   106: 28,
#   107: 42,
#   108: 26,
#   109: 36,
#   110: 89,
#   111: 45,
#   112: 24,
#   113: 41,
#   114: 26,
#   115: 41,
#   116: 58,
#   117: 45,
#   118: 55,
#   119: 128,
#   120: 108,
#   121: 29,
#   122: 30,
#   123: 76,
#   124: 73,
#   125: 41,
#   126: 31,
#   127: 59,
#   128: 137,
#   129: 59,
#   130: 48,
#   131: 53,
#   132: 128,
#   133: 50,
#   134: 50,
#   135: 59,
#   136: 52,
#   137: 100,
#   138: 56,
#   139: 47,
#   140: 51,
#   141: 35,
#   142: 41,
#   143: 35,
#   144: 131,
#   145: 40,
#   146: 39,
#   147: 36,
#   148: 51,
#   149: 38,
#   150: 41,
#   151: 52,
#   152: 122,
#   153: 51,
#   154: 52,
#   155: 40,
#   156: 50,
#   157: 50,
#   158: 47,
#   159: 56,
#   160: 81,
#   161: 56,
#   162: 131,
#   163: 41,
#   164: 124,
#   165: 51,
#   166: 96,
#   167: 68,
#   168: 110,
#   169: 125,
#   170: 48,
#   171: 103,
#   172: 80,
#   173: 58,
#   174: 120,
#   175: 103,
#   176: 56,
#   177: 120,
#   178: 92,
#   179: 70,
#   180: 119,
#   181: 90,
#   182: 93,
#   183: 105,
#   184: 101,
#   185: 68,
#   186: 102,
#   187: 72,
#   188: 101,
#   189: 97,
#   190: 106,
#   191: 87,
#   192: 104,
#   193: 95,
#   194: 72,
#   195: 97,
#   196: 96,
#   197: 92,
#   198: 81,
#   199: 88,
#   200: 93},
#  18: {0: 86,
#   1: 11,
#   2: 84,
#   3: 61,
#   4: 52,
#   5: 12,
#   6: 67,
#   7: 79,
#   8: 7,
#   9: 176,
#   10: 83,
#   11: 14,
#   12: 30,
#   13: 137,
#   14: 37,
#   15: 49,
#   16: 174,
#   17: 49,
#   18: 0,
#   19: 172,
#   20: 131,
#   21: 53,
#   22: 61,
#   23: 18,
#   24: 81,
#   25: 35,
#   26: 54,
#   27: 165,
#   28: 19,
#   29: 170,
#   30: 165,
#   31: 115,
#   32: 3,
#   33: 115,
#   34: 5,
#   35: 65,
#   36: 60,
#   37: 78,
#   38: 60,
#   39: 21,
#   40: 77,
#   41: 83,
#   42: 10,
#   43: 35,
#   44: 48,
#   45: 57,
#   46: 78,
#   47: 78,
#   48: 60,
#   49: 5,
#   50: 152,
#   51: 53,
#   52: 34,
#   53: 46,
#   54: 79,
#   55: 7,
#   56: 7,
#   57: 59,
#   58: 40,
#   59: 21,
#   60: 163,
#   61: 51,
#   62: 75,
#   63: 40,
#   64: 116,
#   65: 40,
#   66: 81,
#   67: 12,
#   68: 123,
#   69: 79,
#   70: 59,
#   71: 98,
#   72: 163,
#   73: 27,
#   74: 68,
#   75: 24,
#   76: 12,
#   77: 17,
#   78: 23,
#   79: 53,
#   80: 97,
#   81: 160,
#   82: 43,
#   83: 160,
#   84: 160,
#   85: 32,
#   86: 48,
#   87: 158,
#   88: 90,
#   89: 76,
#   90: 32,
#   91: 45,
#   92: 16,
#   93: 33,
#   94: 45,
#   95: 50,
#   96: 29,
#   97: 87,
#   98: 83,
#   99: 38,
#   100: 28,
#   101: 67,
#   102: 92,
#   103: 59,
#   104: 23,
#   105: 75,
#   106: 34,
#   107: 78,
#   108: 59,
#   109: 70,
#   110: 118,
#   111: 81,
#   112: 46,
#   113: 75,
#   114: 41,
#   115: 75,
#   116: 91,
#   117: 79,
#   118: 88,
#   119: 142,
#   120: 130,
#   121: 45,
#   122: 45,
#   123: 106,
#   124: 103,
#   125: 71,
#   126: 45,
#   127: 90,
#   128: 144,
#   129: 90,
#   130: 79,
#   131: 84,
#   132: 140,
#   133: 81,
#   134: 81,
#   135: 89,
#   136: 82,
#   137: 123,
#   138: 86,
#   139: 76,
#   140: 81,
#   141: 43,
#   142: 68,
#   143: 43,
#   144: 139,
#   145: 39,
#   146: 64,
#   147: 58,
#   148: 80,
#   149: 43,
#   150: 39,
#   151: 81,
#   152: 135,
#   153: 79,
#   154: 35,
#   155: 40,
#   156: 77,
#   157: 77,
#   158: 71,
#   159: 83,
#   160: 105,
#   161: 82,
#   162: 120,
#   163: 51,
#   164: 131,
#   165: 45,
#   166: 115,
#   167: 91,
#   168: 122,
#   169: 113,
#   170: 63,
#   171: 118,
#   172: 59,
#   173: 77,
#   174: 122,
#   175: 116,
#   176: 51,
#   177: 111,
#   178: 107,
#   179: 56,
#   180: 114,
#   181: 105,
#   182: 76,
#   183: 113,
#   184: 109,
#   185: 79,
#   186: 107,
#   187: 66,
#   188: 105,
#   189: 103,
#   190: 101,
#   191: 96,
#   192: 98,
#   193: 85,
#   194: 72,
#   195: 89,
#   196: 100,
#   197: 97,
#   198: 88,
#   199: 94,
#   200: 87},
#  19: {0: 85,
#   1: 176,
#   2: 148,
#   3: 158,
#   4: 162,
#   5: 172,
#   6: 156,
#   7: 147,
#   8: 173,
#   9: 19,
#   10: 146,
#   11: 171,
#   12: 168,
#   13: 95,
#   14: 165,
#   15: 162,
#   16: 25,
#   17: 161,
#   18: 172,
#   19: 0,
#   20: 100,
#   21: 158,
#   22: 155,
#   23: 167,
#   24: 143,
#   25: 163,
#   26: 157,
#   27: 29,
#   28: 166,
#   29: 23,
#   30: 26,
#   31: 115,
#   32: 168,
#   33: 115,
#   34: 168,
#   35: 150,
#   36: 152,
#   37: 141,
#   38: 152,
#   39: 165,
#   40: 142,
#   41: 138,
#   42: 166,
#   43: 160,
#   44: 156,
#   45: 152,
#   46: 140,
#   47: 140,
#   48: 150,
#   49: 166,
#   50: 59,
#   51: 152,
#   52: 159,
#   53: 156,
#   54: 139,
#   55: 165,
#   56: 165,
#   57: 150,
#   58: 156,
#   59: 161,
#   60: 13,
#   61: 151,
#   62: 137,
#   63: 154,
#   64: 106,
#   65: 154,
#   66: 134,
#   67: 161,
#   68: 96,
#   69: 134,
#   70: 146,
#   71: 120,
#   72: 21,
#   73: 156,
#   74: 138,
#   75: 156,
#   76: 159,
#   77: 158,
#   78: 156,
#   79: 147,
#   80: 119,
#   81: 21,
#   82: 150,
#   83: 19,
#   84: 23,
#   85: 152,
#   86: 148,
#   87: 13,
#   88: 122,
#   89: 131,
#   90: 150,
#   91: 146,
#   92: 156,
#   93: 148,
#   94: 143,
#   95: 141,
#   96: 148,
#   97: 118,
#   98: 121,
#   99: 144,
#   100: 148,
#   101: 131,
#   102: 113,
#   103: 136,
#   104: 149,
#   105: 126,
#   106: 145,
#   107: 124,
#   108: 134,
#   109: 127,
#   110: 84,
#   111: 120,
#   112: 139,
#   113: 123,
#   114: 140,
#   115: 122,
#   116: 109,
#   117: 119,
#   118: 111,
#   119: 33,
#   120: 60,
#   121: 136,
#   122: 135,
#   123: 93,
#   124: 95,
#   125: 120,
#   126: 135,
#   127: 106,
#   128: 29,
#   129: 106,
#   130: 115,
#   131: 112,
#   132: 32,
#   133: 113,
#   134: 113,
#   135: 106,
#   136: 111,
#   137: 66,
#   138: 108,
#   139: 115,
#   140: 111,
#   141: 134,
#   142: 120,
#   143: 134,
#   144: 32,
#   145: 134,
#   146: 122,
#   147: 125,
#   148: 111,
#   149: 132,
#   150: 134,
#   151: 110,
#   152: 38,
#   153: 111,
#   154: 136,
#   155: 133,
#   156: 111,
#   157: 111,
#   158: 114,
#   159: 106,
#   160: 83,
#   161: 106,
#   162: 75,
#   163: 125,
#   164: 40,
#   165: 126,
#   166: 65,
#   167: 94,
#   168: 51,
#   169: 78,
#   170: 114,
#   171: 58,
#   172: 120,
#   173: 102,
#   174: 52,
#   175: 58,
#   176: 120,
#   177: 76,
#   178: 69,
#   179: 118,
#   180: 68,
#   181: 71,
#   182: 106,
#   183: 59,
#   184: 63,
#   185: 94,
#   186: 64,
#   187: 106,
#   188: 66,
#   189: 68,
#   190: 75,
#   191: 76,
#   192: 78,
#   193: 92,
#   194: 99,
#   195: 88,
#   196: 71,
#   197: 74,
#   198: 84,
#   199: 78,
#   200: 88},
#  20: {0: 86,
#   1: 128,
#   2: 64,
#   3: 86,
#   4: 93,
#   5: 124,
#   6: 80,
#   7: 66,
#   8: 128,
#   9: 117,
#   10: 63,
#   11: 122,
#   12: 111,
#   13: 7,
#   14: 104,
#   15: 94,
#   16: 121,
#   17: 95,
#   18: 131,
#   19: 100,
#   20: 0,
#   21: 90,
#   22: 83,
#   23: 117,
#   24: 62,
#   25: 104,
#   26: 88,
#   27: 74,
#   28: 116,
#   29: 117,
#   30: 76,
#   31: 20,
#   32: 128,
#   33: 20,
#   34: 131,
#   35: 77,
#   36: 82,
#   37: 63,
#   38: 82,
#   39: 114,
#   40: 63,
#   41: 57,
#   42: 122,
#   43: 101,
#   44: 91,
#   45: 83,
#   46: 61,
#   47: 61,
#   48: 80,
#   49: 127,
#   50: 43,
#   51: 85,
#   52: 102,
#   53: 92,
#   54: 61,
#   55: 128,
#   56: 128,
#   57: 80,
#   58: 96,
#   59: 112,
#   60: 86,
#   61: 86,
#   62: 62,
#   63: 95,
#   64: 15,
#   65: 95,
#   66: 56,
#   67: 119,
#   68: 9,
#   69: 57,
#   70: 78,
#   71: 36,
#   72: 110,
#   73: 105,
#   74: 67,
#   75: 107,
#   76: 119,
#   77: 114,
#   78: 108,
#   79: 82,
#   80: 36,
#   81: 107,
#   82: 91,
#   83: 106,
#   84: 109,
#   85: 100,
#   86: 86,
#   87: 93,
#   88: 43,
#   89: 58,
#   90: 99,
#   91: 88,
#   92: 121,
#   93: 98,
#   94: 87,
#   95: 82,
#   96: 102,
#   97: 44,
#   98: 48,
#   99: 93,
#   100: 103,
#   101: 65,
#   102: 39,
#   103: 73,
#   104: 111,
#   105: 57,
#   106: 96,
#   107: 54,
#   108: 72,
#   109: 61,
#   110: 23,
#   111: 51,
#   112: 84,
#   113: 56,
#   114: 89,
#   115: 56,
#   116: 40,
#   117: 52,
#   118: 42,
#   119: 71,
#   120: 42,
#   121: 85,
#   122: 86,
#   123: 29,
#   124: 31,
#   125: 59,
#   126: 86,
#   127: 41,
#   128: 92,
#   129: 41,
#   130: 52,
#   131: 47,
#   132: 76,
#   133: 50,
#   134: 50,
#   135: 42,
#   136: 49,
#   137: 40,
#   138: 45,
#   139: 55,
#   140: 50,
#   141: 89,
#   142: 62,
#   143: 89,
#   144: 85,
#   145: 94,
#   146: 67,
#   147: 73,
#   148: 52,
#   149: 89,
#   150: 95,
#   151: 51,
#   152: 71,
#   153: 52,
#   154: 106,
#   155: 94,
#   156: 54,
#   157: 54,
#   158: 61,
#   159: 50,
#   160: 38,
#   161: 50,
#   162: 122,
#   163: 83,
#   164: 83,
#   165: 95,
#   166: 49,
#   167: 47,
#   168: 66,
#   169: 119,
#   170: 72,
#   171: 58,
#   172: 114,
#   173: 60,
#   174: 92,
#   175: 63,
#   176: 94,
#   177: 113,
#   178: 55,
#   179: 104,
#   180: 106,
#   181: 57,
#   182: 114,
#   183: 74,
#   184: 73,
#   185: 68,
#   186: 79,
#   187: 94,
#   188: 79,
#   189: 76,
#   190: 97,
#   191: 69,
#   192: 98,
#   193: 102,
#   194: 84,
#   195: 101,
#   196: 79,
#   197: 76,
#   198: 73,
#   199: 76,
#   200: 96},
#  21: {0: 86,
#   1: 45,
#   2: 32,
#   3: 7,
#   4: 4,
#   5: 42,
#   6: 14,
#   7: 27,
#   8: 47,
#   9: 168,
#   10: 31,
#   11: 39,
#   12: 24,
#   13: 96,
#   14: 16,
#   15: 4,
#   16: 168,
#   17: 5,
#   18: 53,
#   19: 158,
#   20: 90,
#   21: 0,
#   22: 8,
#   23: 34,
#   24: 30,
#   25: 18,
#   26: 1,
#   27: 143,
#   28: 34,
#   29: 164,
#   30: 144,
#   31: 70,
#   32: 50,
#   33: 70,
#   34: 55,
#   35: 13,
#   36: 8,
#   37: 28,
#   38: 8,
#   39: 32,
#   40: 27,
#   41: 33,
#   42: 43,
#   43: 17,
#   44: 5,
#   45: 6,
#   46: 29,
#   47: 29,
#   48: 9,
#   49: 51,
#   50: 121,
#   51: 5,
#   52: 18,
#   53: 7,
#   54: 29,
#   55: 54,
#   56: 54,
#   57: 9,
#   58: 13,
#   59: 32,
#   60: 146,
#   61: 7,
#   62: 27,
#   63: 14,
#   64: 74,
#   65: 14,
#   66: 33,
#   67: 43,
#   68: 84,
#   69: 32,
#   70: 12,
#   71: 53,
#   72: 156,
#   73: 27,
#   74: 22,
#   75: 30,
#   76: 46,
#   77: 39,
#   78: 32,
#   79: 11,
#   80: 53,
#   81: 153,
#   82: 14,
#   83: 152,
#   84: 153,
#   85: 24,
#   86: 13,
#   87: 145,
#   88: 46,
#   89: 31,
#   90: 26,
#   91: 17,
#   92: 52,
#   93: 27,
#   94: 19,
#   95: 18,
#   96: 32,
#   97: 46,
#   98: 42,
#   99: 25,
#   100: 34,
#   101: 27,
#   102: 52,
#   103: 22,
#   104: 44,
#   105: 34,
#   106: 29,
#   107: 37,
#   108: 23,
#   109: 32,
#   110: 84,
#   111: 41,
#   112: 23,
#   113: 36,
#   114: 27,
#   115: 37,
#   116: 54,
#   117: 41,
#   118: 51,
#   119: 125,
#   120: 104,
#   121: 28,
#   122: 30,
#   123: 72,
#   124: 69,
#   125: 37,
#   126: 31,
#   127: 55,
#   128: 135,
#   129: 55,
#   130: 44,
#   131: 48,
#   132: 125,
#   133: 46,
#   134: 46,
#   135: 55,
#   136: 48,
#   137: 96,
#   138: 52,
#   139: 43,
#   140: 47,
#   141: 35,
#   142: 38,
#   143: 35,
#   144: 128,
#   145: 40,
#   146: 36,
#   147: 34,
#   148: 47,
#   149: 38,
#   150: 42,
#   151: 48,
#   152: 119,
#   153: 47,
#   154: 53,
#   155: 41,
#   156: 46,
#   157: 46,
#   158: 43,
#   159: 52,
#   160: 77,
#   161: 52,
#   162: 130,
#   163: 40,
#   164: 122,
#   165: 51,
#   166: 93,
#   167: 64,
#   168: 107,
#   169: 124,
#   170: 46,
#   171: 100,
#   172: 80,
#   173: 55,
#   174: 118,
#   175: 100,
#   176: 56,
#   177: 119,
#   178: 88,
#   179: 71,
#   180: 118,
#   181: 87,
#   182: 93,
#   183: 102,
#   184: 98,
#   185: 66,
#   186: 100,
#   187: 72,
#   188: 99,
#   189: 95,
#   190: 104,
#   191: 85,
#   192: 102,
#   193: 94,
#   194: 71,
#   195: 96,
#   196: 94,
#   197: 90,
#   198: 79,
#   199: 86,
#   200: 92},
#  22: {0: 86,
#   1: 53,
#   2: 24,
#   3: 3,
#   4: 11,
#   5: 50,
#   6: 6,
#   7: 19,
#   8: 55,
#   9: 165,
#   10: 23,
#   11: 47,
#   12: 32,
#   13: 89,
#   14: 24,
#   15: 12,
#   16: 166,
#   17: 13,
#   18: 61,
#   19: 155,
#   20: 83,
#   21: 8,
#   22: 0,
#   23: 42,
#   24: 22,
#   25: 26,
#   26: 6,
#   27: 138,
#   28: 41,
#   29: 162,
#   30: 140,
#   31: 63,
#   32: 58,
#   33: 63,
#   34: 63,
#   35: 6,
#   36: 2,
#   37: 20,
#   38: 2,
#   39: 40,
#   40: 19,
#   41: 26,
#   42: 51,
#   43: 25,
#   44: 12,
#   45: 4,
#   46: 21,
#   47: 21,
#   48: 4,
#   49: 59,
#   50: 116,
#   51: 7,
#   52: 26,
#   53: 14,
#   54: 22,
#   55: 61,
#   56: 61,
#   57: 5,
#   58: 20,
#   59: 39,
#   60: 143,
#   61: 10,
#   62: 20,
#   63: 20,
#   64: 67,
# ...
#   85: 77,
#   86: 81,
#   87: 78,
#   88: 86,
#   89: 83,
#   90: 74,
#   91: 77,
#   92: 69,
#   93: 72,
#   94: 75,
#   95: 75,
#   96: 70,
#   97: 80,
#   98: 80,
#   99: 71,
#   100: 69,
#   101: 77,
#   102: 79,
#   103: 76,
#   104: 66,
#   105: 78,
#   106: 69,
#   107: 77,
#   108: 74,
#   109: 75,
#   110: 79,
#   111: 77,
#   112: 70,
#   113: 75,
#   114: 68,
#   115: 73,
#   116: 74,
#   117: 73,
#   118: 74,
#   119: 69,
#   120: 74,
#   121: 65,
#   122: 64,
#   123: 74,
#   124: 73,
#   125: 69,
#   126: 63,
#   127: 71,
#   128: 63,
#   129: 71,
#   130: 70,
#   131: 70,
#   132: 65,
#   133: 70,
#   134: 70,
#   135: 70,
#   136: 69,
#   137: 70,
#   138: 68,
#   139: 67,
#   140: 67,
#   141: 59,
#   142: 65,
#   143: 59,
#   144: 60,
#   145: 56,
#   146: 63,
#   147: 62,
#   148: 65,
#   149: 57,
#   150: 55,
#   151: 65,
#   152: 62,
#   153: 65,
#   154: 51,
#   155: 55,
#   156: 63,
#   157: 63,
#   158: 61,
#   159: 63,
#   160: 63,
#   161: 62,
#   162: 37,
#   163: 53,
#   164: 53,
#   165: 45,
#   166: 58,
#   167: 58,
#   168: 53,
#   169: 30,
#   170: 51,
#   171: 54,
#   172: 28,
#   173: 51,
#   174: 39,
#   175: 49,
#   176: 39,
#   177: 26,
#   178: 49,
#   179: 29,
#   180: 28,
#   181: 47,
#   182: 15,
#   183: 39,
#   184: 37,
#   185: 37,
#   186: 32,
#   187: 22,
#   188: 30,
#   189: 31,
#   190: 17,
#   191: 33,
#   192: 14,
#   193: 0,
#   194: 24,
#   195: 4,
#   196: 26,
#   197: 27,
#   198: 29,
#   199: 26,
#   200: 6},
#  194: {0: 15,
#   1: 77,
#   2: 80,
#   3: 75,
#   4: 74,
#   5: 74,
#   6: 76,
#   7: 75,
#   8: 74,
#   9: 103,
#   10: 76,
#   11: 73,
#   12: 72,
#   13: 87,
#   14: 72,
#   15: 73,
#   16: 102,
#   17: 72,
#   18: 72,
#   19: 99,
#   20: 84,
#   21: 71,
#   22: 72,
#   23: 70,
#   24: 74,
#   25: 70,
#   26: 71,
#   27: 94,
#   28: 68,
#   29: 98,
#   30: 94,
#   31: 79,
#   32: 69,
#   33: 79,
#   34: 69,
#   35: 70,
#   36: 69,
#   37: 69,
#   38: 69,
#   39: 67,
#   40: 70,
#   41: 70,
#   42: 67,
#   43: 66,
#   44: 67,
#   45: 67,
#   46: 69,
#   47: 69,
#   48: 67,
#   49: 67,
#   50: 87,
#   51: 66,
#   52: 65,
#   53: 66,
#   54: 69,
#   55: 66,
#   56: 66,
#   57: 66,
#   58: 64,
#   59: 64,
#   60: 90,
#   61: 64,
#   62: 64,
#   63: 62,
#   64: 74,
#   65: 62,
#   66: 66,
#   67: 62,
#   68: 75,
#   69: 64,
#   70: 63,
#   71: 68,
#   72: 91,
#   73: 60,
#   74: 60,
#   75: 59,
#   76: 60,
#   77: 59,
#   78: 59,
#   79: 60,
#   80: 66,
#   81: 88,
#   82: 58,
#   83: 88,
#   84: 88,
#   85: 57,
#   86: 58,
#   87: 85,
#   88: 62,
#   89: 59,
#   90: 54,
#   91: 55,
#   92: 56,
#   93: 52,
#   94: 52,
#   95: 52,
#   96: 51,
#   97: 57,
#   98: 56,
#   99: 50,
#   100: 50,
#   101: 52,
#   102: 57,
#   103: 52,
#   104: 50,
#   105: 53,
#   106: 49,
#   107: 53,
#   108: 51,
#   109: 50,
#   110: 63,
#   111: 53,
#   112: 47,
#   113: 51,
#   114: 46,
#   115: 49,
#   116: 52,
#   117: 49,
#   118: 51,
#   119: 70,
#   120: 64,
#   121: 43,
#   122: 42,
#   123: 55,
#   124: 54,
#   125: 44,
#   126: 41,
#   127: 48,
#   128: 71,
#   129: 48,
#   130: 46,
#   131: 47,
#   132: 67,
#   133: 46,
#   134: 46,
#   135: 48,
#   136: 45,
#   137: 59,
#   138: 46,
#   139: 43,
#   140: 44,
#   141: 38,
#   142: 40,
#   143: 38,
#   144: 66,
#   145: 37,
#   146: 39,
#   147: 38,
#   148: 42,
#   149: 36,
#   150: 36,
#   151: 42,
#   152: 63,
#   153: 41,
#   154: 37,
#   155: 35,
#   156: 40,
#   157: 40,
#   158: 36,
#   159: 40,
#   160: 47,
#   161: 39,
#   162: 59,
#   163: 31,
#   164: 58,
#   165: 27,
#   166: 48,
#   167: 38,
#   168: 50,
#   169: 52,
#   170: 27,
#   171: 48,
#   172: 30,
#   173: 27,
#   174: 50,
#   175: 45,
#   176: 21,
#   177: 48,
#   178: 39,
#   179: 22,
#   180: 47,
#   181: 36,
#   182: 30,
#   183: 40,
#   184: 36,
#   185: 16,
#   186: 34,
#   187: 10,
#   188: 33,
#   189: 30,
#   190: 33,
#   191: 24,
#   192: 31,
#   193: 24,
#   194: 0,
#   195: 25,
#   196: 27,
#   197: 24,
#   198: 16,
#   199: 21,
#   200: 20},
#  195: {0: 15,
#   1: 96,
#   2: 105,
#   3: 100,
#   4: 99,
#   5: 93,
#   6: 101,
#   7: 101,
#   8: 93,
#   9: 88,
#   10: 102,
#   11: 93,
#   12: 95,
#   13: 102,
#   14: 95,
#   15: 98,
#   16: 85,
#   17: 97,
#   18: 89,
#   19: 88,
#   20: 101,
#   21: 96,
#   22: 97,
#   23: 90,
#   24: 99,
#   25: 93,
#   26: 96,
#   27: 91,
#   28: 89,
#   29: 82,
#   30: 90,
#   31: 99,
#   32: 86,
#   33: 99,
#   34: 85,
#   35: 95,
#   36: 95,
#   37: 95,
#   38: 95,
#   39: 88,
#   40: 95,
#   41: 95,
#   42: 86,
#   43: 90,
#   44: 92,
#   45: 93,
#   46: 95,
#   47: 95,
#   48: 93,
#   49: 84,
#   50: 93,
#   51: 91,
#   52: 89,
#   53: 91,
#   54: 94,
#   55: 82,
#   56: 82,
#   57: 92,
#   58: 88,
#   59: 85,
#   60: 82,
#   61: 89,
#   62: 90,
#   63: 86,
#   64: 93,
#   65: 86,
#   66: 91,
#   67: 81,
#   68: 92,
#   69: 90,
#   70: 89,
#   71: 91,
#   72: 75,
#   73: 82,
#   74: 86,
#   75: 81,
#   76: 78,
#   77: 79,
#   78: 80,
#   79: 85,
#   80: 89,
#   81: 73,
#   82: 83,
#   83: 73,
#   84: 72,
#   85: 80,
#   86: 83,
#   87: 74,
#   88: 86,
#   89: 84,
#   90: 77,
#   91: 80,
#   92: 73,
#   93: 75,
#   94: 77,
#   95: 78,
#   96: 73,
#   97: 80,
#   98: 80,
#   99: 73,
#   100: 72,
#   101: 78,
#   102: 79,
#   103: 78,
#   104: 69,
#   105: 79,
#   106: 72,
#   107: 78,
#   108: 76,
#   109: 76,
#   110: 77,
#   111: 77,
#   112: 72,
#   113: 76,
#   114: 70,
#   115: 74,
#   116: 74,
#   117: 74,
#   118: 74,
#   119: 65,
#   120: 71,
#   121: 68,
#   122: 66,
#   123: 72,
#   124: 72,
#   125: 69,
#   126: 66,
#   127: 70,
#   128: 58,
#   129: 70,
#   130: 70,
#   131: 70,
#   132: 61,
#   133: 70,
#   134: 70,
#   135: 70,
#   136: 69,
#   137: 67,
#   138: 68,
#   139: 67,
#   140: 68,
#   141: 62,
#   142: 66,
#   143: 62,
#   144: 56,
#   145: 59,
#   146: 65,
#   147: 64,
#   148: 66,
#   149: 59,
#   150: 58,
#   151: 66,
#   152: 58,
#   153: 65,
#   154: 54,
#   155: 58,
#   156: 64,
#   157: 64,
#   158: 61,
#   159: 63,
#   160: 62,
#   161: 62,
#   162: 34,
#   163: 55,
#   164: 49,
#   165: 48,
#   166: 55,
#   167: 57,
#   168: 49,
#   169: 27,
#   170: 52,
#   171: 51,
#   172: 32,
#   173: 51,
#   174: 35,
#   175: 46,
#   176: 42,
#   177: 23,
#   178: 47,
#   179: 32,
#   180: 24,
#   181: 45,
#   182: 18,
#   183: 35,
#   184: 34,
#   185: 37,
#   186: 28,
#   187: 25,
#   188: 27,
#   189: 28,
#   190: 13,
#   191: 31,
#   192: 9,
#   193: 4,
#   194: 25,
#   195: 0,
#   196: 23,
#   197: 25,
#   198: 28,
#   199: 24,
#   200: 5},
#  196: {0: 14,
#   1: 104,
#   2: 95,
#   3: 96,
#   4: 97,
#   5: 101,
#   6: 96,
#   7: 92,
#   8: 102,
#   9: 76,
#   10: 92,
#   11: 100,
#   12: 99,
#   13: 79,
#   14: 97,
#   15: 96,
#   16: 75,
#   17: 96,
#   18: 100,
#   19: 71,
#   20: 79,
#   21: 94,
#   22: 93,
#   23: 97,
#   24: 89,
#   25: 95,
#   26: 93,
#   27: 70,
#   28: 95,
#   29: 71,
#   30: 69,
#   31: 81,
#   32: 97,
#   33: 81,
#   34: 96,
#   35: 89,
#   36: 90,
#   37: 85,
#   38: 90,
#   39: 94,
#   40: 86,
#   41: 85,
#   42: 94,
#   43: 92,
#   44: 91,
#   45: 89,
#   46: 85,
#   47: 85,
#   48: 88,
#   49: 94,
#   50: 69,
#   51: 88,
#   52: 91,
#   53: 90,
#   54: 84,
#   55: 93,
#   56: 93,
#   57: 87,
#   58: 89,
#   59: 91,
#   60: 63,
#   61: 86,
#   62: 81,
#   63: 87,
#   64: 73,
#   65: 87,
#   66: 80,
#   67: 90,
#   68: 70,
#   69: 79,
#   70: 84,
#   71: 75,
#   72: 64,
#   73: 86,
#   74: 79,
#   75: 86,
#   76: 87,
#   77: 87,
#   78: 86,
#   79: 82,
#   80: 73,
#   81: 61,
#   82: 83,
#   83: 60,
#   84: 61,
#   85: 83,
#   86: 82,
#   87: 57,
#   88: 72,
#   89: 75,
#   90: 80,
#   91: 79,
#   92: 84,
#   93: 78,
#   94: 76,
#   95: 75,
#   96: 78,
#   97: 67,
#   98: 68,
#   99: 75,
#   100: 77,
#   101: 70,
#   102: 65,
#   103: 73,
#   104: 77,
#   105: 69,
#   106: 75,
#   107: 67,
#   108: 71,
#   109: 67,
#   110: 55,
#   111: 65,
#   112: 72,
#   113: 66,
#   114: 71,
#   115: 64,
#   116: 59,
#   117: 63,
#   118: 60,
#   119: 44,
#   120: 47,
#   121: 68,
#   122: 67,
#   123: 53,
#   124: 53,
#   125: 60,
#   126: 66,
#   127: 55,
#   128: 43,
#   129: 55,
#   130: 59,
#   131: 57,
#   132: 41,
#   133: 58,
#   134: 58,
#   135: 55,
#   136: 56,
#   137: 44,
#   138: 54,
#   139: 57,
#   140: 55,
#   141: 64,
#   142: 58,
#   143: 64,
#   144: 38,
#   145: 63,
#   146: 58,
#   147: 60,
#   148: 54,
#   149: 62,
#   150: 63,
#   151: 53,
#   152: 37,
#   153: 53,
#   154: 64,
#   155: 62,
#   156: 53,
#   157: 53,
#   158: 52,
#   159: 49,
#   160: 41,
#   161: 49,
#   162: 44,
#   163: 56,
#   164: 31,
#   165: 55,
#   166: 32,
#   167: 41,
#   168: 26,
#   169: 40,
#   170: 48,
#   171: 27,
#   172: 51,
#   173: 40,
#   174: 24,
#   175: 22,
#   176: 48,
#   177: 34,
#   178: 24,
#   179: 46,
#   180: 28,
#   181: 22,
#   182: 41,
#   183: 13,
#   184: 10,
#   185: 27,
#   186: 7,
#   187: 35,
#   188: 5,
#   189: 4,
#   190: 17,
#   191: 11,
#   192: 18,
#   193: 26,
#   194: 27,
#   195: 23,
#   196: 0,
#   197: 3,
#   198: 14,
#   199: 7,
#   200: 20},
#  197: {0: 13,
#   1: 102,
#   2: 91,
#   3: 93,
#   4: 94,
#   5: 98,
#   6: 92,
#   7: 88,
#   8: 99,
#   9: 79,
#   10: 88,
#   11: 97,
#   12: 95,
#   13: 77,
#   14: 94,
#   15: 93,
#   16: 78,
#   17: 92,
#   18: 97,
#   19: 74,
#   20: 76,
#   21: 90,
#   22: 89,
#   23: 94,
#   24: 85,
#   25: 92,
#   26: 90,
#   27: 71,
#   28: 92,
#   29: 75,
#   30: 70,
#   31: 77,
#   32: 94,
#   33: 77,
#   34: 94,
#   35: 86,
#   36: 86,
#   37: 82,
#   38: 86,
#   39: 91,
#   40: 82,
#   41: 81,
#   42: 92,
#   43: 88,
#   44: 87,
#   45: 85,
#   46: 81,
#   47: 81,
#   48: 85,
#   49: 92,
#   50: 68,
#   51: 85,
#   52: 88,
#   53: 86,
#   54: 80,
#   55: 91,
#   56: 91,
#   57: 84,
#   58: 85,
#   59: 88,
#   60: 65,
#   61: 83,
#   62: 77,
#   63: 84,
#   64: 70,
#   65: 84,
#   66: 77,
#   67: 87,
#   68: 68,
#   69: 76,
#   70: 80,
#   71: 72,
#   72: 67,
#   73: 83,
#   74: 75,
#   75: 83,
#   76: 85,
#   77: 84,
#   78: 83,
#   79: 79,
#   80: 70,
#   81: 64,
#   82: 79,
#   83: 63,
#   84: 64,
#   85: 80,
#   86: 78,
#   87: 60,
#   88: 69,
#   89: 71,
#   90: 77,
#   91: 76,
#   92: 81,
#   93: 75,
#   94: 73,
#   95: 72,
#   96: 75,
#   97: 63,
#   98: 64,
#   99: 72,
#   100: 74,
#   101: 67,
#   102: 61,
#   103: 69,
#   104: 75,
#   105: 65,
#   106: 72,
#   107: 64,
#   108: 67,
#   109: 63,
#   110: 53,
#   111: 62,
#   112: 68,
#   113: 62,
#   114: 68,
#   115: 60,
#   116: 55,
#   117: 59,
#   118: 56,
#   119: 45,
#   120: 46,
#   121: 64,
#   122: 64,
#   123: 50,
#   124: 50,
#   125: 57,
#   126: 63,
#   127: 52,
#   128: 46,
#   129: 52,
#   130: 55,
#   131: 53,
#   132: 43,
#   133: 54,
#   134: 54,
#   135: 51,
#   136: 52,
#   137: 42,
#   138: 51,
#   139: 53,
#   140: 52,
#   141: 61,
#   142: 54,
#   143: 61,
#   144: 41,
#   145: 61,
#   146: 54,
#   147: 56,
#   148: 50,
#   149: 59,
#   150: 60,
#   151: 50,
#   152: 38,
#   153: 50,
#   154: 62,
#   155: 59,
#   156: 49,
#   157: 49,
#   158: 49,
#   159: 46,
#   160: 38,
#   161: 45,
#   162: 48,
#   163: 52,
#   164: 34,
#   165: 52,
#   166: 30,
#   167: 37,
#   168: 27,
#   169: 43,
#   170: 44,
#   171: 26,
#   172: 50,
#   173: 36,
#   174: 27,
#   175: 22,
#   176: 46,
#   177: 37,
#   178: 22,
#   179: 45,
#   180: 32,
#   181: 20,
#   182: 42,
#   183: 15,
#   184: 11,
#   185: 24,
#   186: 10,
#   187: 33,
#   188: 8,
#   189: 5,
#   190: 20,
#   191: 7,
#   192: 21,
#   193: 27,
#   194: 24,
#   195: 25,
#   196: 3,
#   197: 0,
#   198: 11,
#   199: 3,
#   200: 21},
#  198: {0: 13,
#   1: 91,
#   2: 81,
#   3: 81,
#   4: 83,
#   5: 88,
#   6: 81,
#   7: 77,
#   8: 89,
#   9: 90,
#   10: 78,
#   11: 87,
#   12: 84,
#   13: 74,
#   14: 82,
#   15: 82,
#   16: 90,
#   17: 81,
#   18: 88,
#   19: 84,
#   20: 73,
#   21: 79,
#   22: 78,
#   23: 83,
#   24: 75,
#   25: 81,
#   26: 78,
#   27: 78,
#   28: 82,
#   29: 86,
#   30: 78,
#   31: 71,
#   32: 84,
#   33: 71,
#   34: 85,
#   35: 74,
#   36: 75,
#   37: 71,
#   38: 75,
#   39: 80,
#   40: 71,
#   41: 71,
#   42: 82,
#   43: 77,
#   44: 76,
#   45: 74,
#   46: 71,
#   47: 71,
#   48: 73,
#   49: 82,
#   50: 71,
#   51: 73,
#   52: 77,
#   53: 75,
#   54: 70,
#   55: 82,
#   56: 82,
#   57: 73,
#   58: 74,
#   59: 77,
#   60: 74,
#   61: 71,
#   62: 66,
#   63: 72,
#   64: 64,
#   65: 72,
#   66: 66,
#   67: 77,
#   68: 64,
#   69: 65,
#   70: 69,
#   71: 63,
#   72: 78,
#   73: 72,
#   74: 64,
#   75: 72,
#   76: 75,
#   77: 74,
#   78: 72,
#   79: 67,
#   80: 61,
#   81: 75,
#   82: 68,
#   83: 74,
#   84: 75,
#   85: 69,
#   86: 67,
#   87: 70,
#   88: 59,
#   89: 60,
#   90: 66,
#   91: 64,
#   92: 72,
#   93: 64,
#   94: 62,
#   95: 60,
#   96: 64,
#   97: 54,
#   98: 54,
#   99: 61,
#   100: 64,
#   101: 56,
#   102: 52,
#   103: 58,
#   104: 65,
#   105: 54,
#   106: 61,
#   107: 53,
#   108: 56,
#   109: 53,
#   110: 50,
#   111: 52,
#   112: 57,
#   113: 51,
#   114: 57,
#   115: 50,
#   116: 47,
#   117: 49,
#   118: 47,
#   119: 53,
#   120: 48,
#   121: 53,
#   122: 52,
#   123: 44,
#   124: 44,
#   125: 46,
#   126: 52,
#   127: 43,
#   128: 57,
#   129: 43,
#   130: 45,
#   131: 44,
#   132: 52,
#   133: 44,
#   134: 44,
#   135: 42,
#   136: 43,
#   137: 43,
#   138: 41,
#   139: 42,
#   140: 42,
#   141: 50,
#   142: 43,
#   143: 50,
#   144: 51,
#   145: 50,
#   146: 43,
#   147: 45,
#   148: 40,
#   149: 48,
#   150: 50,
#   151: 40,
#   152: 47,
#   153: 39,
#   154: 52,
#   155: 49,
#   156: 39,
#   157: 39,
#   158: 38,
#   159: 36,
#   160: 34,
#   161: 35,
#   162: 56,
#   163: 41,
#   164: 44,
#   165: 42,
#   166: 32,
#   167: 29,
#   168: 34,
#   169: 51,
#   170: 33,
#   171: 31,
#   172: 46,
#   173: 26,
#   174: 39,
#   175: 28,
#   176: 36,
#   177: 45,
#   178: 23,
#   179: 38,
#   180: 41,
#   181: 20,
#   182: 41,
#   183: 25,
#   184: 21,
#   185: 12,
#   186: 21,
#   187: 26,
#   188: 19,
#   189: 16,
#   190: 29,
#   191: 8,
#   192: 28,
#   193: 29,
#   194: 16,
#   195: 28,
#   196: 14,
#   197: 11,
#   198: 0,
#   199: 7,
#   200: 23},
#  199: {0: 11,
#   1: 98,
#   2: 88,
#   3: 89,
#   4: 90,
#   5: 94,
#   6: 88,
#   7: 85,
#   8: 95,
#   9: 83,
#   10: 85,
#   11: 93,
#   12: 91,
#   13: 77,
#   14: 90,
#   15: 89,
#   16: 82,
#   17: 88,
#   18: 94,
#   19: 78,
#   20: 76,
#   21: 86,
#   22: 85,
#   23: 90,
#   24: 82,
#   25: 88,
#   26: 86,
#   27: 74,
#   28: 88,
#   29: 79,
#   30: 73,
#   31: 76,
#   32: 90,
#   33: 76,
#   34: 90,
#   35: 82,
#   36: 83,
#   37: 78,
#   38: 83,
#   39: 87,
#   40: 79,
#   41: 78,
#   42: 88,
#   43: 84,
#   44: 83,
#   45: 82,
#   46: 78,
#   47: 78,
#   48: 81,
#   49: 88,
#   50: 70,
#   51: 81,
#   52: 84,
#   53: 82,
#   54: 77,
#   55: 87,
#   56: 87,
#   57: 80,
#   58: 81,
#   59: 84,
#   60: 69,
#   61: 79,
#   62: 73,
#   63: 80,
#   64: 69,
#   65: 80,
#   66: 74,
#   67: 83,
#   68: 67,
#   69: 72,
#   70: 77,
#   71: 69,
#   72: 71,
#   73: 79,
#   74: 71,
#   75: 79,
#   76: 81,
#   77: 80,
#   78: 79,
#   79: 75,
#   80: 67,
#   81: 68,
#   82: 75,
#   83: 67,
#   84: 68,
#   85: 76,
#   86: 74,
#   87: 64,
#   88: 66,
#   89: 67,
#   90: 73,
#   91: 72,
#   92: 78,
#   93: 71,
#   94: 69,
#   95: 68,
#   96: 71,
#   97: 61,
#   98: 61,
#   99: 68,
#   100: 70,
#   101: 63,
#   102: 58,
#   103: 65,
#   104: 71,
#   105: 62,
#   106: 68,
#   107: 60,
#   108: 64,
#   109: 60,
#   110: 53,
#   111: 59,
#   112: 64,
#   113: 59,
#   114: 64,
#   115: 57,
#   116: 53,
#   117: 56,
#   118: 54,
#   119: 49,
#   120: 47,
#   121: 60,
#   122: 60,
#   123: 48,
#   124: 49,
#   125: 53,
#   126: 59,
#   127: 49,
#   128: 50,
#   129: 49,
#   130: 52,
#   131: 51,
#   132: 46,
#   133: 51,
#   134: 51,
#   135: 49,
#   136: 50,
#   137: 43,
#   138: 48,
#   139: 50,
#   140: 49,
#   141: 57,
#   142: 50,
#   143: 57,
#   144: 45,
#   145: 57,
#   146: 51,
#   147: 52,
#   148: 47,
#   149: 55,
#   150: 56,
#   151: 47,
#   152: 41,
#   153: 46,
#   154: 58,
#   155: 55,
#   156: 46,
#   157: 46,
#   158: 45,
#   159: 43,
#   160: 37,
#   161: 42,
#   162: 50,
#   163: 48,
#   164: 38,
#   165: 48,
#   166: 31,
#   167: 35,
#   168: 30,
#   169: 45,
#   170: 40,
#   171: 28,
#   172: 48,
#   173: 33,
#   174: 31,
#   175: 24,
#   176: 42,
#   177: 39,
#   178: 22,
#   179: 41,
#   180: 34,
#   181: 20,
#   182: 40,
#   183: 19,
#   184: 15,
#   185: 20,
#   186: 14,
#   187: 30,
#   188: 12,
#   189: 9,
#   190: 22,
#   191: 6,
#   192: 22,
#   193: 26,
#   194: 21,
#   195: 24,
#   196: 7,
#   197: 3,
#   198: 7,
#   199: 0,
#   200: 20},
#  200: {0: 10,
#   1: 93,
#   2: 100,
#   3: 96,
#   4: 95,
#   5: 90,
#   6: 97,
#   7: 96,
#   8: 90,
#   9: 89,
#   10: 97,
#   11: 90,
#   12: 91,
#   13: 97,
#   14: 91,
#   15: 93,
#   16: 87,
#   17: 93,
#   18: 87,
#   19: 88,
#   20: 96,
#   21: 92,
#   22: 92,
#   23: 87,
#   24: 94,
#   25: 89,
#   26: 92,
#   27: 89,
#   28: 86,
#   29: 83,
#   30: 89,
#   31: 94,
#   32: 84,
#   33: 94,
#   34: 83,
#   35: 90,
#   36: 90,
#   37: 90,
#   38: 90,
#   39: 85,
#   40: 90,
#   41: 90,
#   42: 83,
#   43: 86,
#   44: 88,
#   45: 88,
#   46: 90,
#   47: 90,
#   48: 88,
#   49: 81,
#   50: 89,
#   51: 87,
#   52: 85,
#   53: 86,
#   54: 89,
#   55: 80,
#   56: 80,
#   57: 87,
#   58: 84,
#   59: 82,
#   60: 82,
#   61: 84,
#   62: 85,
#   63: 82,
#   64: 88,
#   65: 82,
#   66: 86,
#   67: 78,
#   68: 87,
#   69: 84,
#   70: 84,
#   71: 85,
#   72: 76,
#   73: 79,
#   74: 81,
#   75: 78,
#   76: 75,
#   77: 76,
#   78: 77,
#   79: 81,
#   80: 83,
#   81: 74,
#   82: 79,
#   83: 74,
#   84: 73,
#   85: 76,
#   86: 79,
#   87: 74,
#   88: 81,
#   89: 79,
#   90: 73,
#   91: 75,
#   92: 70,
#   93: 71,
#   94: 73,
#   95: 73,
#   96: 69,
#   97: 75,
#   98: 75,
#   99: 69,
#   100: 68,
#   101: 73,
#   102: 74,
#   103: 73,
#   104: 66,
#   105: 73,
#   106: 68,
#   107: 73,
#   108: 71,
#   109: 71,
#   110: 73,
#   111: 72,
#   112: 68,
#   113: 71,
#   114: 66,
#   115: 69,
#   116: 69,
#   117: 69,
#   118: 69,
#   119: 63,
#   120: 67,
#   121: 63,
#   122: 62,
#   123: 67,
#   124: 67,
#   125: 64,
#   126: 61,
#   127: 65,
#   128: 59,
#   129: 65,
#   130: 65,
#   131: 65,
#   132: 60,
#   133: 65,
#   134: 65,
#   135: 65,
#   136: 64,
#   137: 64,
#   138: 63,
#   139: 62,
#   140: 63,
#   141: 58,
#   142: 61,
#   143: 58,
#   144: 55,
#   145: 55,
#   146: 60,
#   147: 59,
#   148: 61,
#   149: 55,
#   150: 54,
#   151: 60,
#   152: 56,
#   153: 60,
#   154: 51,
#   155: 54,
#   156: 59,
#   157: 59,
#   158: 56,
#   159: 57,
#   160: 57,
#   161: 57,
#   162: 38,
#   163: 51,
#   164: 48,
#   165: 45,
#   166: 51,
#   167: 52,
#   168: 47,
#   169: 32,
#   170: 47,
#   171: 47,
#   172: 32,
#   173: 46,
#   174: 36,
#   175: 43,
#   176: 38,
#   177: 27,
#   178: 43,
#   179: 30,
#   180: 27,
#   181: 40,
#   182: 20,
#   183: 33,
#   184: 31,
#   185: 32,
#   186: 26,
#   187: 21,
#   188: 24,
#   189: 25,
#   190: 14,
#   191: 27,
#   192: 11,
#   193: 6,
#   194: 20,
#   195: 5,
#   196: 20,
#   197: 21,
#   198: 23,
#   199: 20,
#   200: 0}}
